# %% [markdown]
# ## GPT 기반 2023 수능 국어 문제 풀기
#
# ### 프로그램 개요
# 이 프로그램은 OpenAI의 GPT 모델을 활용하여 대학수학능력시험(수능) 문제를 자동으로 풀이하고 모델과 프롬프트의 성능을 평가하는 시스템입니다. 다양한 프롬프트 방법론을 적용하여 모델의 문제 해결 능력을 체계적으로 분석하고 비교할 수 있습니다.

# %% [markdown]
# 라이브러리 임포트 및 설정

# %%
# 필요한 라이브러리 import
import requests          # GitHub에서 데이터 다운로드용
import openai           # OpenAI API 사용
from openai import OpenAI
from typing import Dict, List, Tuple  # 타입 힌팅
import time             # 실행 시간 측정 및 API 호출 간격 조절
import re               # 정규표현식 (답안 파싱용)
import pandas as pd     # 데이터 처리 및 결과 저장
import tiktoken         # OpenAI 토큰 계산
import random           # API 실패 시 랜덤 답안 생성
from dataclasses import dataclass  # 결과 데이터 구조화
from dotenv import load_dotenv     # 환경변수 로드
import os               # 파일 시스템 작업
from pathlib import Path           # 경로 처리
import json             # JSON 파일 처리

# %% [markdown]
# ## 📋 테스트 결과 데이터 구조 정의
#
# - @dataclass 데코레이터를 사용하여 테스트 결과를 체계적으로 저장
# - AI 모델별, 프롬프트 전략별 성능 지표를 구조화된 형태로 관리
# - 정답률, 실행시간, 상세 결과 등 다양한 메트릭을 포함
# - 타입 힌트를 통해 각 필드의 데이터 타입을 명시하여 코드 가독성 향상

# %%
# OpenAI API 설정
load_dotenv()  # .env 파일에서 환경변수 로드
openai.api_key = os.getenv("OPENAI_API_KEY")  # API 키 설정

@dataclass
class TestResult:
    """테스트 결과를 저장하는 데이터 클래스"""
    model: str              # 사용된 AI 모델명 (예: gpt-4o, gpt-4o-mini)
    prompt_method: str      # 사용된 프롬프트 전략명
    correct_answers: int    # 맞힌 문제 개수
    total_questions: int    # 전체 문제 개수
    score: float           # 정답률 (백분율)
    total_score: float     # 획득한 총 점수
    execution_time: float  # 전체 실행 시간 (초)
    detailed_results: pd.DataFrame  # 문제별 상세 결과 데이터

# %%
# 프롬프트 템플릿
PROMPTS = {
    # 기본적인 zero-shot 프롬프트 (추가 설명 없이 문제만 제시)
    "zero_shot": """다음 지문을 읽고 문제를 풀어주세요.
    
    지문:
    {paragraph}
    
    문제: {question}
    {question_plus}
    
    선택지:
    {choices1}
    {choices2}
    {choices3}
    {choices4}
    {choices5}
    
    문제를 풀어줘. 정답만 번호로 줘

    ###답변 형태 ###
    정답: """,
    
    # 감정적 호소를 통한 동기부여 프롬프트
    "emotional_appeal": """🎯 인생에서 최고로 중요한 수능 국어 문제입니다.
    당신이 소중하게 생각하는 할머니께서 당신이 좋은 성적을 얻기만을 기다리고 계십니다. 당신의 실력을 보여주세요.
    이 문제는 많은 수험생들이 어려워하는 유형입니다. 하지만 당신은 분명히 풀 수 있습니다! 
    차근차근 읽고, 단계별로 생각해서 최선의 답을 찾아주세요.
    자신감을 가지고 열정적으로 풀어보세요.
    
    지문:
    {paragraph}
    
    ❓ 문제: {question}
    
    {question_plus}
    
    선택지를 신중하게 검토해보세요:
    {choices1}
    {choices2}
    {choices3}
    {choices4}
    {choices5}
    
    깊이 생각해보고, 지문의 내용을 정확히 파악한 후 답을 선택하세요.
    당신은 반드시 정답을 찾을 수 있습니다.
    
    이 문제를 틀리면 정말 좋은 기회를 놓치게 될 것입니다. 신중하게, 그리고 확신을 가지고 답해주세요.
    
    ###답변 형태 ###
    정답: """,

    # 전문가 역할 부여 프롬프트 (체계적 분석 유도)
    "expert_role": """
    당신은 국어교육 전문가입니다. 다음 지문과 문제를 분석하여 정확한 답을 제시해주세요.
    
    지문:
    {paragraph}
    
    문제: {question}
    {question_plus}
    
    선택지:
    {choices1}
    {choices2}
    {choices3}
    {choices4}
    {choices5}
    
    ###답변 형태 ###
    정답: """
    }

print("데이터 클래스 및 프롬프트 정의 완료!")
# Out:
# 데이터 클래스 및 프롬프트 정의 완료!

# %% [markdown]
# ## 🧠 한국어 수능 문제 해결 클래스 정의
#
# GitHub에서 2023년 수능 국어 데이터를 자동으로 로드하는 기능 구현
# OpenAI API 클라이언트와 토큰 계산기(tiktoken)를 초기화하여 AI 모델 활용 준비
# 개별 문제 단위와 지문별 그룹화 두 가지 데이터 구조로 유연한 처리 지원
# 원본 JSON 데이터를 파싱하여 문제별 정보(지문, 선택지, 정답, 배점 등)를 구조화
# 예외 처리를 통해 네트워크 오류나 데이터 로드 실패 상황에 대응
#
# ---
# ### 💡 추가 정보
# >tiktoken은 OpenAI의 토큰 계산 라이브러리로, API 비용 관리와 토큰 제한 확인에 필수적임. requests.raise_for_status()는 HTTP 오류 상태 코드에 대해 예외를 발생시켜 안전한 API 호출을 보장함.

# %%
class KoreanSuneungSolver:
    def __init__(self):
        self.data = None                # 개별 문제 단위로 저장된 데이터
        self.grouped_data = None        # 지문별로 그룹화된 데이터 (효율적 처리용)
        self.results = {}              # 테스트 결과를 저장하는 딕셔너리
        self.client = OpenAI()         # OpenAI API 클라이언트
        self.tokenizer = tiktoken.encoding_for_model("gpt-4o")  # 토큰 계산용
        
    def load_data(self):
        """GitHub에서 2023년 수능 국어 데이터 로드 및 지문별 그룹화"""
        github_url = "https://raw.githubusercontent.com/NomaDamas/KICE_slayer_AI_Korean/master/data/2023_11_KICE.json"
        try:
            response = requests.get(github_url, timeout=30)
            response.raise_for_status()
            raw_data = response.json()
            
            # 기존 방식으로 변환 (호환성 유지)
            total_result = []
            for data in raw_data:
                paragraph_id = data['id']
                paragraph = data['paragraph']
                data_type = data['type']
                problems_lst = data['problems']
                
                for problem in problems_lst:
                    question = problem['question']
                    choices = [f"{i+1}번 {choice}" for i, choice in enumerate(problem['choices'])]
                    answer = problem['answer']
                    score = problem['score']
                    question_plus = problem.get('question_plus', '')
                    
                    problem_dict = {
                        'paragraph_id': paragraph_id,
                        'type': data_type,
                        'paragraph': paragraph,
                        'question': question,
                        'question_plus': question_plus,
                        'choices': choices,
                        'answer': answer,
                        'score': score,
                    }
                    total_result.append(problem_dict)
            
            self.data = total_result
            
            # 지문별로 그룹화 (멘토 스타일)
            self.grouped_data = self._group_by_paragraph(raw_data)
            
            print(f"데이터 로드 완료: {len(self.data)} 문제, {len(self.grouped_data)} 지문")
            return True
        except Exception as e:
            print(f"데이터 로드 실패: {e}")
            return False
    
    def _group_by_paragraph(self, raw_data):
        """원본 데이터를 지문별로 그룹화"""
        grouped = []
        for data in raw_data:
            paragraph_data = {
                'id': data['id'],
                'type': data['type'],
                'paragraph': data['paragraph'],
                'problems': []
            }
            
            for problem in data['problems']:
                problem_dict = {
                    'question': problem['question'],
                    'question_plus': problem.get('question_plus', ''),
                    'choices': problem['choices'],  # 원본 형태 유지
                    'answer': problem['answer'],
                    'score': problem['score']
                }
                paragraph_data['problems'].append(problem_dict)
            
            grouped.append(paragraph_data)
        
        return grouped
    
# 인스턴스 생성 및 데이터 로드
solver = KoreanSuneungSolver()
print("KoreanSuneungSolver 클래스 정의 완료!")
# Out:
# KoreanSuneungSolver 클래스 정의 완료!

# %% [markdown]
# ## 🛠️ 핵심 유틸리티 메서드 구현
#
# - 답안 정규화: AI 모델의 다양한 출력 형태를 1-5번 정수로 변환하는 로직 구현
# - 선택지 형태를 자동 감지하여 "1번, 2번..." 형식으로 통일화
# - 예외 처리와 함께 안전한 API 호출 및 랜덤 답안 fallback 제공
#
# 💡 추가 정보: temperature=0은 AI 모델의 창의성을 최소화하여 일관된 답변을 얻는 설정. 동적 메서드 바인딩을 통해 클래스 외부에서 정의한 함수를 클래스 메서드로 추가할 수 있습니다.

# %%
# KoreanSuneungSolver 클래스에 유틸리티 메서드 추가
def normalize_answer(self, text: str) -> int:
    """답안 정규화"""
    if hasattr(text, 'content'):
        result = text.content
    else:
        result = str(text)
        
    result = result.split("정답:")[-1]
    for num in range(1, 6):
        if str(num) in result:
            return num
        
    return random.randint(1, 5)
    
def prediction(self, prompt: str, model: str = "gpt-4o"):
    """OpenAI API 호출"""
    try:
        completion = self.client.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": prompt}],
            max_tokens=100,
            temperature=0
        )
        return completion.choices[0].message
    except Exception as e:
        print(f"API 호출 실패: {e}")
        return None
    
def build_prompt_for_problem(self, prompt_name: str, paragraph: str, problem: dict) -> str:
    """개별 문제에 대한 프롬프트 생성"""
    if prompt_name not in PROMPTS:
        raise ValueError(f"지원하지 않는 프롬프트: {prompt_name}")
    
    prompt_template = PROMPTS[prompt_name]
    question_plus_text = f"추가 정보: {problem['question_plus']}" if problem['question_plus'] else ""
        
    # 선택지 포맷팅 (멘토 스타일에 맞춰 조정)
    choices = problem['choices']
    if isinstance(choices[0], str) and not choices[0].startswith('1번'):
        # 원본 형태라면 번호 추가
        formatted_choices = [f"{i+1}번 {choice}" for i, choice in enumerate(choices)]
    else:
        # 이미 번호가 있다면 그대로 사용
        formatted_choices = choices
        
    prompt = prompt_template.format(
        paragraph=paragraph,
        question=problem['question'],
        question_plus=question_plus_text,
        choices1=formatted_choices[0],
        choices2=formatted_choices[1],
        choices3=formatted_choices[2],
        choices4=formatted_choices[3],
        choices5=formatted_choices[4],
    )
        
    return prompt

# 메서드를 클래스에 바인딩
KoreanSuneungSolver.normalize_answer = normalize_answer
KoreanSuneungSolver.prediction = prediction
KoreanSuneungSolver.build_prompt_for_problem = build_prompt_for_problem
    
print("유틸리티 메서드 추가 완료!")
# Out:
# 유틸리티 메서드 추가 완료!

# %% [markdown]
# ## 📝 지문별 문제 해결 엔진
#
# - 실시간 진행상황 표시: 각 지문과 문제별로 ID, 길이, 문제 수를 콘솔에 출력하여 진행상황 모니터링
# - 문제별 성능 측정: 개별 문제의 처리 시간을 측정하고 정답 여부를 즉시 확인
# - 상세 결과 수집: 예측값, 정답, 획득점수, AI 응답 텍스트 등을 구조화하여 저장
# - API 호출 제한 대응: 0.5초 간격으로 API 호출하여 OpenAI 레이트 리밋 준수
# - 실패 안전장치: API 호출 실패 시 랜덤 답안으로 fallback하여 테스트 연속성 보장
#
# ---
# > 💡 추가 정보: time.sleep(0.5)는 API 레이트 리밋을 피하기 위한 중요한 설정. 문자열 슬라이싱과 조건부 표현식을 사용하여 긴 텍스트를 안전하게 출력 형태로 변환합니다.

# %%
def solve_paragraph_problems(self, paragraph_data: dict, prompt_name: str, model: str) -> List[dict]:
    """한 지문의 모든 문제를 해결하고 실시간 결과 출력"""
    paragraph = paragraph_data['paragraph']
    problems = paragraph_data['problems']
    paragraph_id = paragraph_data['id']
        
    print(f"\n📖 지문 ID: {paragraph_id}")
    print(f"   지문 길이: {len(paragraph)}자, 문제 수: {len(problems)}")
    print("-" * 50)
        
    results = []
        
    for i, problem in enumerate(problems):
        problem_start_time = time.time()
            
        # 프롬프트 생성
        prompt = self.build_prompt_for_problem(prompt_name, paragraph, problem)
            
        # API 호출
        response = self.prediction(prompt, model)
        if response is None:
            pred = random.randint(1, 5)
            response_text = "API 호출 실패"
        else:
            pred = self.normalize_answer(response)
            response_text = response.content
            
        # 정답 확인
        correct = problem['answer']
        score = problem['score']
        is_correct = (pred == correct)
        earned_score = score if is_correct else 0
            
        problem_time = time.time() - problem_start_time
            
        # 실시간 결과 출력
        result_symbol = "✅" if is_correct else "❌"
        print(f"  {result_symbol} 문제 {i+1}: 예측={pred}, 정답={correct}, 점수={earned_score}/{score}")
        print(f"     응답: {response_text[:100]}{'...' if len(response_text) > 100 else ''}")
        print(f"     처리시간: {problem_time:.2f}초")
            
        # 결과 저장
        result_data = {
            'paragraph_id': paragraph_id,
            'problem_num': i + 1,
            'question': problem['question'][:100] + "..." if len(problem['question']) > 100 else problem['question'],
            'pred': pred,
            'answer': correct,
            'score': earned_score,
            'max_score': score,
            'is_correct': is_correct,
            'response': response_text,
            'processing_time': problem_time
        }
        results.append(result_data)
            
        # API 제한 고려
        time.sleep(0.5)
        
    return results
# 메서드를 클래스에 바인딩
KoreanSuneungSolver.solve_paragraph_problems = solve_paragraph_problems

print("문제 해결 메서드 추가 완료!")
# Out:
# 문제 해결 메서드 추가 완료!

# %% [markdown]
# ## 🧪 통합 테스트 실행 시스템
#
# - 문제 수 제한 기능: max_questions 파라미터로 테스트 범위를 유연하게 조절 가능
# - 진행상황 실시간 모니터링: 지문별 진행률과 누적 점수를 실시간으로 표시하여 테스트 현황 파악
# - 자동 결과 저장: 테스트 결과를 CSV 파일로 자동 저장하여 후속 분석에 활용
# - 종합 성능 지표 계산: 정답률, 총점, 실행시간 등 다양한 성능 메트릭을 자동 계산
# - 구조화된 결과 반환: TestResult 데이터클래스로 결과를 체계적으로 관리하고 비교 분석 지원

# %%
def run_test(self, prompt_name: str, model: str = "gpt-4o", max_questions: int = None) -> TestResult:
        """지문별 그룹화된 테스트 실행"""
        if self.grouped_data is None:
            raise ValueError("데이터를 먼저 로드해주세요.")
        
        print(f"\n{'='*60}")
        print(f"🚀 테스트 시작: {model} + {prompt_name}")
        print(f"⏰ 시작 시간: {time.strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"{'='*60}")
        
        start_time = time.time()
        all_results = []
        total_score = 0
        question_count = 0
        
        # 문제 수 제한 처리
        test_data = self.grouped_data
        if max_questions:
            # 문제 수를 제한하는 경우, 지문별로 누적하여 계산
            limited_data = []
            current_count = 0
            for paragraph_data in self.grouped_data:
                if current_count >= max_questions:
                    break
                remaining = max_questions - current_count
                if len(paragraph_data['problems']) <= remaining:
                    limited_data.append(paragraph_data)
                    current_count += len(paragraph_data['problems'])
                else:
                    # 지문의 일부 문제만 포함
                    truncated_data = paragraph_data.copy()
                    truncated_data['problems'] = paragraph_data['problems'][:remaining]
                    limited_data.append(truncated_data)
                    break
            test_data = limited_data
        
        # 각 지문별로 문제 해결
        for paragraph_idx, paragraph_data in enumerate(test_data):
            print(f"\n🔍 진행률: {paragraph_idx + 1}/{len(test_data)} 지문")
            
            paragraph_results = self.solve_paragraph_problems(paragraph_data, prompt_name, model)
            all_results.extend(paragraph_results)
            
            # 점수 누적
            for result in paragraph_results:
                total_score += result['score']
                question_count += 1
            
            print(f"   지문 완료 - 현재 총점: {total_score}점")
        
        end_time = time.time()
        execution_time = end_time - start_time
        
        # DataFrame 생성
        df = pd.DataFrame(all_results)
        
        # 통계 계산
        correct_answers = df['is_correct'].sum()
        total_questions = len(df)
        max_possible_score = df['max_score'].sum()
        percentage = (correct_answers / total_questions) * 100
        
        # CSV 저장
        os.makedirs("data/results", exist_ok=True)
        csv_path = f"data/results/{prompt_name}_{model}.csv"
        df.to_csv(csv_path, index=False, encoding='utf-8')
        
        result = TestResult(
            model=model,
            prompt_method=prompt_name,
            correct_answers=correct_answers,
            total_questions=total_questions,
            score=percentage,
            total_score=total_score,
            execution_time=execution_time,
            detailed_results=df
        )
        
        self.results[f"{prompt_name}_{model}"] = result
        
        print(f"\n{'='*60}")
        print(f"✅ 테스트 완료: {prompt_name} + {model}")
        print(f"⏰ 완료 시간: {time.strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"📊 최종 결과:")
        print(f"   총점: {total_score}/{max_possible_score}점 ({total_score/max_possible_score*100:.1f}%)")
        print(f"   정답률: {percentage:.1f}% ({correct_answers}/{total_questions})")
        print(f"   소요시간: {execution_time:.2f}초")
        print(f"{'='*60}")
        
        return result
    
# 메서드를 클래스에 바인딩
KoreanSuneungSolver.run_test = run_test

print("테스트 실행 메서드 추가 완료!")
# Out:
# 테스트 실행 메서드 추가 완료!

# %% [markdown]
# 분석 및 출력 메서드(1/2)

# %%
def print_progress(self, current: int, total: int, desc: str = "진행중"):
        """진행률 출력 함수"""
        percentage = (current / total) * 100
        bar_length = 30
        filled_length = int(bar_length * current // total)
        bar = '█' * filled_length + '-' * (bar_length - filled_length)
        print(f'\r{desc}: |{bar}| {current}/{total} ({percentage:.1f}%)', end='', flush=True)
        if current == total:
            print()
    
def print_comparison_table(self):
        """모든 결과를 비교 테이블로 출력"""
        if not self.results:
            print("비교할 결과가 없습니다.")
            return
        
        print("\n" + "="*100)
        print("📊 종합 결과 비교 테이블")
        print("="*100)
        
        # 테이블 헤더
        print(f"{'모델':<15} {'프롬프트':<18} {'정답률':<8} {'총점':<8} {'정답수/총문제':<12} {'실행시간':<10}")
        print("-" * 100)
        
        # 결과 정렬 (정답률 기준 내림차순)
        sorted_results = sorted(self.results.items(), key=lambda x: x[1].score, reverse=True)
        
        for name, result in sorted_results:
            accuracy = f"{result.score:.1f}%"
            score_ratio = f"{result.total_score:.0f}"
            answer_ratio = f"{result.correct_answers}/{result.total_questions}"
            exec_time = f"{result.execution_time:.1f}초"
            
            print(f"{result.model:<15} {result.prompt_method:<18} {accuracy:<8} {score_ratio:<8} {answer_ratio:<12} {exec_time:<10}")
        
        print("-" * 100)
        
        # 최고 성능 강조
        if sorted_results:
            best_result = sorted_results[0][1]
            print(f"!! 최고 성능: {best_result.model} + {best_result.prompt_method}")
            print(f"   정답률: {best_result.score:.1f}% | 총점: {best_result.total_score:.0f}점 | 시간: {best_result.execution_time:.1f}초")
        
        # 프롬프트별 평균 성능
        self.print_prompt_analysis()
        
        # 모델별 평균 성능
        self.print_model_analysis()
    
def print_prompt_analysis(self):
        """프롬프트별 성능 분석"""
        print(f"\n📈 프롬프트별 평균 성능:")
        prompt_stats = {}
        
        for result in self.results.values():
            prompt = result.prompt_method
            if prompt not in prompt_stats:
                prompt_stats[prompt] = {'scores': [], 'times': []}
            prompt_stats[prompt]['scores'].append(result.score)
            prompt_stats[prompt]['times'].append(result.execution_time)
        
        for prompt, stats in prompt_stats.items():
            avg_score = sum(stats['scores']) / len(stats['scores'])
            avg_time = sum(stats['times']) / len(stats['times'])
            print(f"  {prompt:<18}: 평균 정답률 {avg_score:.1f}% | 평균 시간 {avg_time:.1f}초")
    
def print_model_analysis(self):
        """모델별 성능 분석"""
        print(f"\n🤖 모델별 평균 성능:")
        model_stats = {}
        
        for result in self.results.values():
            model = result.model
            if model not in model_stats:
                model_stats[model] = {'scores': [], 'times': []}
            model_stats[model]['scores'].append(result.score)
            model_stats[model]['times'].append(result.execution_time)
        
        for model, stats in model_stats.items():
            avg_score = sum(stats['scores']) / len(stats['scores'])
            avg_time = sum(stats['times']) / len(stats['times'])
            print(f"  {model:<15}: 평균 정답률 {avg_score:.1f}% | 평균 시간 {avg_time:.1f}초")
    
# 메서드들을 클래스에 바인딩
KoreanSuneungSolver.print_progress = print_progress
KoreanSuneungSolver.print_comparison_table = print_comparison_table
KoreanSuneungSolver.print_prompt_analysis = print_prompt_analysis
KoreanSuneungSolver.print_model_analysis = print_model_analysis

print("분석 및 출력 메서드들 (1/2) 추가 완료!")
# Out:
# 분석 및 출력 메서드들 (1/2) 추가 완료!

# %% [markdown]
# ## 🧪 분석 및 출력 메서드(2/2)

# %%
def show_sample_responses(self):
        """각 프롬프트 타입에 대한 정답과 오답의 예시"""
        print(f"\n📋 프롬프트별 응답 예시:")
        
        for i, (name, result) in enumerate(self.results.items()):
            df = result.detailed_results
            
            # 정답 예시
            correct_samples = df[df['is_correct'] == True]
            incorrect_samples = df[df['is_correct'] == False]
            
            if len(correct_samples) > 0 and len(incorrect_samples) > 0:
                print(f"\n{'='*60}")
                print(f"📝 {result.model} + {result.prompt_method}")
                print(f"{'='*60}")
                
                # 정답 예시
                true_sample = correct_samples.iloc[0]
                print(f"✅ 정답 예시:")
                print(f"  문제: {true_sample['question'][:100]}...")
                print(f"  예측: {true_sample['pred']} | 정답: {true_sample['answer']}")
                print(f"  응답: {true_sample['response'][:150]}...\n")
                
                # 오답 예시
                false_sample = incorrect_samples.iloc[0]
                print(f"❌ 오답 예시:")
                print(f"  문제: {false_sample['question'][:100]}...")
                print(f"  예측: {false_sample['pred']} | 정답: {false_sample['answer']}")
                print(f"  응답: {false_sample['response'][:150]}...\n")

def analyze_results(self):
        """결과 분석 및 출력 (기존 함수 개선)"""
        if not self.results:
            print("분석할 결과가 없습니다.")
            return
        
        # 비교 테이블 출력
        self.print_comparison_table()
        
        # 상세 분석
        print(f"\n🔍 상세 분석:")
        self.show_sample_responses()
    
def export_detailed_results(self):
        """상세 결과를 JSON과 CSV로 내보내기"""
        if not self.results:
            print("내보낼 결과가 없습니다.")
            return
        
        # JSON 형태로 요약 결과 저장
        summary_data = []
        for name, result in self.results.items():
            summary_data.append({
                'model': str(result.model),                  
                'prompt_method': str(result.prompt_method),
                'total_score': float(result.total_score),     
                'score_percentage': float(result.score),
                'correct_answers': int(result.correct_answers), 
                'total_questions': int(result.total_questions),
                'execution_time': float(result.execution_time)
            })
        
        os.makedirs("data/results", exist_ok=True)
        
        # 요약 결과 저장
        with open("data/results/comprehensive_summary.json", 'w', encoding='utf-8') as f:
            json.dump(summary_data, f, ensure_ascii=False, indent=2)
        
        # CSV 형태로도 요약 저장
        summary_df = pd.DataFrame(summary_data)
        summary_df.to_csv("data/results/comprehensive_summary.csv", index=False, encoding='utf-8')
        
        print(f"\n💾 종합 결과 저장 완료:")
        print(f"   - JSON 요약: data/results/comprehensive_summary.json")
        print(f"   - CSV 요약: data/results/comprehensive_summary.csv")
        print(f"   - 개별 상세 결과: data/results/ 폴더의 각 CSV 파일들")
    
# 메서드들을 클래스에 바인딩
KoreanSuneungSolver.show_sample_responses = show_sample_responses
KoreanSuneungSolver.analyze_results = analyze_results
KoreanSuneungSolver.export_detailed_results = export_detailed_results

print("분석 및 출력 메서드들 (2/2) 추가 완료!")
# Out:
# 분석 및 출력 메서드들 (2/2) 추가 완료!

# %% [markdown]
# 종합 테스트 메서드

# %%
def run_comprehensive_test(self, models: List[str] = None, max_questions: int = None):
        """종합 테스트 실행 - 모든 프롬프트와 모델 조합 테스트"""
        if models is None:
            models = ["gpt-4o-mini", "gpt-4o"]
        
        # 3가지 프롬프트 기법 사용
        prompt_methods = ["zero_shot", "emotional_appeal", "expert_role"]
        
        print("=" * 80)
        print("🎯 2023 수능 국어 AI 풀이 프로그램 (종합 테스트)")
        print("=" * 80)
        print(f"📊 테스트할 문제 수: {max_questions if max_questions else '전체'}")
        print(f"🤖 모델: {', '.join(models)}")
        print(f"💡 프롬프트 기법: {', '.join(prompt_methods)}")
        print(f"🔥 총 테스트 조합: {len(models)} × {len(prompt_methods)} = {len(models) * len(prompt_methods)}개")
        print("=" * 80)
        
        total_combinations = len(models) * len(prompt_methods)
        current_combination = 0
        
        for model in models:
            for prompt_method in prompt_methods:
                current_combination += 1
                try:
                    print(f"\n🚀 테스트 조합 {current_combination}/{total_combinations}: {model} + {prompt_method}")
                    self.run_test(prompt_method, model, max_questions)
                    print(f"✅ 조합 {current_combination} 완료")
                    print("\n" + "-" * 60)
                except Exception as e:
                    print(f"❌ 테스트 실패 - {model} + {prompt_method}: {e}")
                    print("-" * 60)
        
        # 테스트 완료 후 결과 테이블 출력
        self.print_comparison_table()
    
# 메서드를 클래스에 바인딩
KoreanSuneungSolver.run_comprehensive_test = run_comprehensive_test

print("종합 테스트 메서드 추가 완료!")
print("모든 클래스 메서드가 정의되었습니다!")
# Out:
# 종합 테스트 메서드 추가 완료!
# 모든 클래스 메서드가 정의되었습니다!

# %% [markdown]
# 데이터 로드 및 확인

# %%
# 데이터 로드
if not solver.load_data():
    print("데이터 로드에 실패했습니다.")
else:
    print(f"✅ 데이터 로드 성공!")
    print(f"📊 총 문제 수: {len(solver.data)}")
    print(f"📖 총 지문 수: {len(solver.grouped_data)}")
    
    # 첫 번째 지문 미리보기
    if solver.grouped_data:
        first_paragraph = solver.grouped_data[0]
        print(f"\n🔍 첫 번째 지문 미리보기:")
        print(f"   ID: {first_paragraph['id']}")
        print(f"   타입: {first_paragraph['type']}")
        print(f"   지문 길이: {len(first_paragraph['paragraph'])}자")
        print(f"   문제 수: {len(first_paragraph['problems'])}")
# Out:
# 데이터 로드 완료: 45 문제, 11 지문
# ✅ 데이터 로드 성공!
# 📊 총 문제 수: 45
# 📖 총 지문 수: 11
#
# 🔍 첫 번째 지문 미리보기:
#    ID: 2023_11_KICE_1-3
#    타입: 0
#    지문 길이: 978자
#    문제 수: 3

# %% [markdown]
# 단일 테스트 실행 (테스트용)

# %%
# 단일 프롬프트와 모델로 소규모 테스트 실행
print("🧪 단일 테스트 실행 (5문제로 제한)")
print("=" * 50)

# 테스트 실행 (5문제만)
test_result = solver.run_test(
    prompt_name="zero_shot",
    model="gpt-4o-mini", 
    max_questions=5
)

print(f"\n📊 단일 테스트 결과:")
print(f"   모델: {test_result.model}")
print(f"   프롬프트: {test_result.prompt_method}")
print(f"   정답률: {test_result.score:.1f}%")
print(f"   총점: {test_result.total_score}점")
print(f"   정답 수: {test_result.correct_answers}/{test_result.total_questions}")
# Out:
# 🧪 단일 테스트 실행 (5문제로 제한)
# ==================================================
#
# ============================================================
# 🚀 테스트 시작: gpt-4o-mini + zero_shot
# ⏰ 시작 시간: 2025-05-25 17:41:30
# ============================================================
#
# 🔍 진행률: 1/2 지문
#
# 📖 지문 ID: 2023_11_KICE_1-3
#    지문 길이: 978자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4
#      처리시간: 1.32초
#   ❌ 문제 2: 예측=4, 정답=5, 점수=0/3
#      응답: 정답: 4번
#      처리시간: 0.94초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 0.90초
#    지문 완료 - 현재 총점: 4점
#
# 🔍 진행률: 2/2 지문
#
# 📖 지문 ID: 2023_11_KICE_4-9
#    지문 길이: 2158자, 문제 수: 2
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 0.93초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5
#      처리시간: 1.21초
#    지문 완료 - 현재 총점: 8점
#
# ============================================================
# ✅ 테스트 완료: zero_shot + gpt-4o-mini
# ⏰ 완료 시간: 2025-05-25 17:41:38
# 📊 최종 결과:
#    총점: 8/11점 (72.7%)
#    정답률: 80.0% (4/5)
#    소요시간: 7.82초
# ============================================================
#
# 📊 단일 테스트 결과:
#    모델: gpt-4o-mini
#    프롬프트: zero_shot
#    정답률: 80.0%
#    총점: 8점
#    정답 수: 4/5

# %% [markdown]
# 결과 분석 및 시각화

# %%
# 결과 분석
print("📈 결과 분석")
print("=" * 50)

solver.analyze_results()
# Out:
# 📈 결과 분석
# ==================================================
#
# ====================================================================================================
# 📊 종합 결과 비교 테이블
# ====================================================================================================
# 모델              프롬프트               정답률      총점       정답수/총문제      실행시간
# ----------------------------------------------------------------------------------------------------
# gpt-4o          zero_shot          95.6%    96       43/45        97.2초
# gpt-4o          emotional_appeal   84.4%    85       38/45        123.4초
# gpt-4o          expert_role        82.2%    83       37/45        122.2초
# gpt-4o-mini     zero_shot          71.1%    71       32/45        97.7초
# gpt-4o-mini     expert_role        57.8%    58       26/45        189.4초
# gpt-4o-mini     emotional_appeal   55.6%    56       25/45        140.1초
# ----------------------------------------------------------------------------------------------------
# !! 최고 성능: gpt-4o + zero_shot
#    정답률: 95.6% | 총점: 96점 | 시간: 97.2초
#
# 📈 프롬프트별 평균 성능:
#   zero_shot         : 평균 정답률 83.3% | 평균 시간 97.5초
#   emotional_appeal  : 평균 정답률 70.0% | 평균 시간 131.8초
#   expert_role       : 평균 정답률 70.0% | 평균 시간 155.8초
#
# 🤖 모델별 평균 성능:
#   gpt-4o-mini    : 평균 정답률 61.5% | 평균 시간 142.4초
#   gpt-4o         : 평균 정답률 87.4% | 평균 시간 114.3초
#
# 🔍 상세 분석:
#
# 📋 프롬프트별 응답 예시:
#
# ============================================================
# 📝 gpt-4o-mini + zero_shot
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4...
#
# ❌ 오답 예시:
#   문제: 다음은 학생이 독서 후 작성한 글의 일부이다. [A]를 바탕으로 ⓐ～ⓔ를 이해한 내용으로 가장 적절한 것은?...
#   예측: 4 | 정답: 5
#   응답: 정답: 4번...
#
#
# ============================================================
# 📝 gpt-4o-mini + emotional_appeal
# ============================================================
# ✅ 정답 예시:
#   문제: 다음은 학생이 독서 후 작성한 글의 일부이다. [A]를 바탕으로 ⓐ～ⓔ를 이해한 내용으로 가장 적절한 것은?...
#   예측: 5 | 정답: 5
#   응답: 정답: 5번 ⓓ에는 ‘독자 자신에게서 답을 찾는 질문’이, ⓔ에는 그에 대한 답을 ‘독자의 경험’에서 찾아내는 모습이 나타난다.
#
# 이유: ⓓ에서 학생은 "내가 진정으로 좋아하는 일이 무엇인지 나에게 묻게 되었다."라는 질문을 통해 자신에게서 답을 찾고 있으며, ⓔ에서...
#
# ❌ 오답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 2 | 정답: 4
#   응답: 정답: 2번
#
# 이유: 지문에서는 다른 독자와의 소통이 독자의 인식의 폭을 확장하도록 돕는다고 명시적으로 언급하지 않고 있습니다. 오히려 독자는 독서 모임이나 독서 동아리에서 다른 독자들과 나누는 과정을 통해 자신의 인식을 심화 확장할 수 있다고 설명하고 있습니다. 따라...
#
#
# ============================================================
# 📝 gpt-4o-mini + expert_role
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4번
#
# 해설: 지문에서는 독자의 배경지식, 관점, 읽기 환경, 과제 등이 독자의 의미 구성에 영향을 미친다고 언급하고 있지만, 이를 '독자 요인'으로 명시적으로 구분하지는 않았습니다. 따라서 4번 선택지는 지문의 내용과 일치하지 않는 것으로 판단됩니다....
#
# ❌ 오답 예시:
#   문제: 다음은 학생이 독서 후 작성한 글의 일부이다. [A]를 바탕으로 ⓐ～ⓔ를 이해한 내용으로 가장 적절한 것은?...
#   예측: 4 | 정답: 5
#   응답: 정답: 4번
#
# 해설:
# - ⓐ는 "음악 시간에 들었던 베토벤의 교향곡 <합창>이 위대한 작품인 이유는 무엇일까?"라는 질문으로, 이는 독자가 책에서 답을 찾으려는 질문입니다.
# - ⓑ는 "이 곡이 낭만주의 음악의 특징을 보여 준다고 했다."라는 내용으로, 이는 책에서 제시...
#
#
# ============================================================
# 📝 gpt-4o + zero_shot
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4번...
#
# ❌ 오답 예시:
#   문제: 윗글을 읽고 추론한 내용으로 적절하지 않은 것은?...
#   예측: 5 | 정답: 4
#   응답: 정답: 5번...
#
#
# ============================================================
# 📝 gpt-4o + emotional_appeal
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4번 독자의 배경지식, 관점, 읽기 환경, 과제는 독자의 의미 구성에 영향을 주는 독자 요인이다.
#
# 지문에서는 독자의 배경지식이나 관점 등의 독자 요인과 읽기 환경이나 과제 등의 상황 요인이 다르다고 언급하고 있습니다. 따라서 읽기 환경과 과제는 독자 요인이 ...
#
# ❌ 오답 예시:
#   문제: 윗글을 바탕으로 <보기>를 이해한 내용으로 가장 적절한 것은? [3점]...
#   예측: 1 | 정답: 2
#   응답: 정답: 2번 (나)에서 을의 손해가 80임이 증명된 경우, 갑이 을에게 100을 지급해야 하고 법원이 감액할 수 있다.
#
# 설명:
# - (가) 상황에서는 위약금 약정이 없으므로, 을은 손해를 증명해야 하고, 증명된 손해액인 80만큼만 받을 수 있습니다.
# - (나) 상황에...
#
#
# ============================================================
# 📝 gpt-4o + expert_role
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4번 독자의 배경지식, 관점, 읽기 환경, 과제는 독자의 의미 구성에 영향을 주는 독자 요인이다.
#
# 지문에서는 독자의 배경지식이나 관점 등의 독자 요인과 읽기 환경이나 과제 등의 상황 요인이 다르다고 언급하고 있습니다. 따라서 읽기 환경과 과제는 독자 요인이 ...
#
# ❌ 오답 예시:
#   문제: 윗글을 바탕으로 <보기>를 이해한 내용으로 가장 적절한 것은? [3점]...
#   예측: 1 | 정답: 2
#   응답: 정답: 2번 (나)에서 을의 손해가 80임이 증명된 경우, 갑이 을에게 100을 지급해야 하고 법원이 감액할 수 있다....

# %% [markdown]
# 결과 저장 및 내보내기

# %%
# 결과 저장
print("💾 결과 저장")
print("=" * 50)

solver.export_detailed_results()

# 저장된 파일 확인
import os
if os.path.exists("data/results"):
    print(f"\n📁 저장된 파일 목록:")
    for file in os.listdir("data/results"):
        file_path = os.path.join("data/results", file)
        file_size = os.path.getsize(file_path)
        print(f"   - {file} ({file_size} bytes)")
# Out:
# 💾 결과 저장
# ==================================================
#
# 💾 종합 결과 저장 완료:
#    - JSON 요약: data/results/comprehensive_summary.json
#    - CSV 요약: data/results/comprehensive_summary.csv
#    - 개별 상세 결과: data/results/ 폴더의 각 CSV 파일들
#
# 📁 저장된 파일 목록:
#    - expert_role_gpt-4o.csv (5479 bytes)
#    - emotional_appeal_gpt-4o-mini.csv (4921 bytes)
#    - emotional_appeal_gpt-4o.csv (4533 bytes)
#    - zero_shot_gpt-4o-mini.csv (797 bytes)
#    - expert_role_gpt-4o-mini.csv (5389 bytes)
#    - comprehensive_summary.csv (150 bytes)
#    - comprehensive_summary.json (220 bytes)
#    - zero_shot_gpt-4o.csv (1573 bytes)

# %% [markdown]
# ## 🧪 전체 테스트 실행

# %%
# 전체 테스트 실행

print("🔥 전체 테스트 실행 (모든 문제)")
print("⚠️  경고: 시간과 API 비용이 많이 소요됩니다!")
print("=" * 60)

# 전체 모델로 테스트
full_models = ["gpt-4o-mini", "gpt-4o"]

# 전체 테스트 실행
solver.run_comprehensive_test(
    models=full_models, 
    max_questions=None  # 전체 문제
)

# 최종 결과 분석
solver.analyze_results()
solver.export_detailed_results()


print("전체 테스트 셀이 준비되었습니다.")
print("필요시 위의 주석을 해제하고 실행하세요.")
# Out:
# 🔥 전체 테스트 실행 (모든 문제)
# ⚠️  경고: 시간과 API 비용이 많이 소요됩니다!
# ============================================================
# ================================================================================
# 🎯 2023 수능 국어 AI 풀이 프로그램 (종합 테스트)
# ================================================================================
# 📊 테스트할 문제 수: 전체
# 🤖 모델: gpt-4o-mini, gpt-4o
# 💡 프롬프트 기법: zero_shot, emotional_appeal, expert_role
# 🔥 총 테스트 조합: 2 × 3 = 6개
# ================================================================================
#
# 🚀 테스트 조합 1/6: gpt-4o-mini + zero_shot
#
# ============================================================
# 🚀 테스트 시작: gpt-4o-mini + zero_shot
# ⏰ 시작 시간: 2025-05-25 17:42:25
# ============================================================
#
# 🔍 진행률: 1/11 지문
#
# 📖 지문 ID: 2023_11_KICE_1-3
#    지문 길이: 978자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4
#      처리시간: 1.19초
#   ❌ 문제 2: 예측=4, 정답=5, 점수=0/3
#      응답: 정답: 4번
#      처리시간: 1.00초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 6.91초
#    지문 완료 - 현재 총점: 4점
#
# 🔍 진행률: 2/11 지문
#
# 📖 지문 ID: 2023_11_KICE_4-9
#    지문 길이: 2158자, 문제 수: 6
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 0.78초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5
#      처리시간: 1.61초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 0.87초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번
#      처리시간: 0.95초
#   ✅ 문제 5: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5
#      처리시간: 1.23초
#   ✅ 문제 6: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번
#      처리시간: 1.17초
#    지문 완료 - 현재 총점: 17점
#
# 🔍 진행률: 3/11 지문
#
# 📖 지문 ID: 2023_11_KICE_10-13
#    지문 길이: 1192자, 문제 수: 4
# --------------------------------------------------
#   ❌ 문제 1: 예측=1, 정답=4, 점수=0/2
#      응답: 정답: 1번
#      처리시간: 0.83초
#   ❌ 문제 2: 예측=1, 정답=5, 점수=0/2
#      응답: 정답: 1
#      처리시간: 9.21초
#   ✅ 문제 3: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2
#      처리시간: 0.79초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5
#      처리시간: 1.26초
#    지문 완료 - 현재 총점: 22점
#
# 🔍 진행률: 4/11 지문
#
# 📖 지문 ID: 2023_11_KICE_14-17
#    지문 길이: 1810자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 1.33초
#   ❌ 문제 2: 예측=3, 정답=4, 점수=0/2
#      응답: 정답: 3번
#      처리시간: 0.51초
#   ❌ 문제 3: 예측=3, 정답=4, 점수=0/2
#      응답: 정답: 3
#      처리시간: 0.50초
#   ✅ 문제 4: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1
#      처리시간: 0.63초
#    지문 완료 - 현재 총점: 27점
#
# 🔍 진행률: 5/11 지문
#
# 📖 지문 ID: 2023_11_KICE_18-21
#    지문 길이: 1934자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 1.00초
#   ✅ 문제 2: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 1.01초
#   ❌ 문제 3: 예측=4, 정답=3, 점수=0/2
#      응답: 정답: 4
#      처리시간: 0.95초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5
#      처리시간: 0.84초
#    지문 완료 - 현재 총점: 34점
#
# 🔍 진행률: 6/11 지문
#
# 📖 지문 ID: 2023_11_KICE_22-26
#    지문 길이: 1747자, 문제 수: 5
# --------------------------------------------------
#   ❌ 문제 1: 예측=3, 정답=1, 점수=0/2
#      응답: 정답: 3번
#      처리시간: 1.04초
#   ❌ 문제 2: 예측=2, 정답=5, 점수=0/2
#      응답: 정답: 2번
#      처리시간: 0.87초
#   ❌ 문제 3: 예측=4, 정답=3, 점수=0/3
#      응답: 정답: 4번
#      처리시간: 0.94초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3
#      처리시간: 1.22초
#   ✅ 문제 5: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 18.91초
#    지문 완료 - 현재 총점: 38점
#
# 🔍 진행률: 7/11 지문
#
# 📖 지문 ID: 2023_11_KICE_27-30
#    지문 길이: 2441자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1
#      처리시간: 1.12초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#      처리시간: 1.31초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 0.71초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2
#      처리시간: 0.66초
#    지문 완료 - 현재 총점: 47점
#
# 🔍 진행률: 8/11 지문
#
# 📖 지문 ID: 2023_11_KICE_31-34
#    지문 길이: 785자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 0.83초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 0.82초
#   ❌ 문제 3: 예측=1, 정답=2, 점수=0/2
#      응답: 정답: 1
#      처리시간: 0.83초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=3/3
#      응답: 정답: 3번
#      처리시간: 0.83초
#    지문 완료 - 현재 총점: 54점
#
# 🔍 진행률: 9/11 지문
#
# 📖 지문 ID: 2023_11_KICE_35-37
#    지문 길이: 1039자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1
#      처리시간: 0.93초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5
#      처리시간: 1.16초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3
#      처리시간: 0.95초
#    지문 완료 - 현재 총점: 60점
#
# 🔍 진행률: 10/11 지문
#
# 📖 지문 ID: 2023_11_KICE_38-42
#    지문 길이: 2367자, 문제 수: 5
# --------------------------------------------------
#   ❌ 문제 1: 예측=2, 정답=4, 점수=0/2
#      응답: 정답: 2
#      처리시간: 0.88초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 0.99초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3
#      처리시간: 1.06초
#   ❌ 문제 4: 예측=5, 정답=2, 점수=0/3
#      응답: 정답: 5번
#      처리시간: 0.84초
#   ❌ 문제 5: 예측=1, 정답=4, 점수=0/2
#      응답: 정답: 1번
#      처리시간: 0.89초
#    지문 완료 - 현재 총점: 64점
#
# 🔍 진행률: 11/11 지문
#
# 📖 지문 ID: 2023_11_KICE_43-45
#    지문 길이: 819자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#      처리시간: 0.80초
#   ✅ 문제 2: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2
#      처리시간: 0.63초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번
#      처리시간: 1.17초
#    지문 완료 - 현재 총점: 71점
#
# ============================================================
# ✅ 테스트 완료: zero_shot + gpt-4o-mini
# ⏰ 완료 시간: 2025-05-25 17:44:03
# 📊 최종 결과:
#    총점: 71/100점 (71.0%)
#    정답률: 71.1% (32/45)
#    소요시간: 97.71초
# ============================================================
# ✅ 조합 1 완료
#
# ------------------------------------------------------------
#
# 🚀 테스트 조합 2/6: gpt-4o-mini + emotional_appeal
#
# ============================================================
# 🚀 테스트 시작: gpt-4o-mini + emotional_appeal
# ⏰ 시작 시간: 2025-05-25 17:44:03
# ============================================================
#
# 🔍 진행률: 1/11 지문
#
# 📖 지문 ID: 2023_11_KICE_1-3
#    지문 길이: 978자, 문제 수: 3
# --------------------------------------------------
#   ❌ 문제 1: 예측=2, 정답=4, 점수=0/2
#      응답: 정답: 2번
#
# 이유: 지문에서는 다른 독자와의 소통이 독자의 인식의 폭을 확장하도록 돕는다고 명시적으로 언급하지 않고 있습니다. 오히려 독자는 독서 모임이나 독서 동아리에서 다른 ...
#      처리시간: 2.66초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번 ⓓ에는 ‘독자 자신에게서 답을 찾는 질문’이, ⓔ에는 그에 대한 답을 ‘독자의 경험’에서 찾아내는 모습이 나타난다.
#
# 이유: ⓓ에서 학생은 "내가 진정으로 좋아하는 ...
#      처리시간: 2.22초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#
# 이유: ㉠에서 언급된 "다른 독자와 소통하는 즐거움"은 독서 모임이나 독서 동아리 등에서 다른 독자들과의 상호작용을 통해 경험하는 것을 의미합니다. 1번은 개인적으로...
#      처리시간: 2.07초
#    지문 완료 - 현재 총점: 5점
#
# 🔍 진행률: 2/11 지문
#
# 📖 지문 ID: 2023_11_KICE_4-9
#    지문 길이: 2158자, 문제 수: 6
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 (가)는 유서의 특성과 의의를 설명하였고, (나)는 유서 편찬에서 특정 학문의 수용 양상을 시기별로 소개하였다.
#      처리시간: 1.37초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#
# 이유: 지문에서 언급된 바에 따르면, 중국의 유서는 기존 서적에서 필요한 부분을 뽑아 배열할 뿐 상호 비교하거나 편찬자의 해석을 가하지 않았다고 명시되어 있습니다. ...
#      처리시간: 2.33초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#
# 이유: ㉮에서 언급된 "평가를 더하는 저술"의 성격은 ㉡에서 서학을 활용하여 중국 학문의 진보성을 확인하고자 한 것과는 직접적인 관련이 없습니다. ㉡에서 이익이 서학...
#      처리시간: 5.46초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 주자학에 매몰되어 세상의 여러 이치를 연구하지 않는 것은 널리 배우고 익히는 앎의 바른 방법이 아닐 것이다.
#
# 이수광은 주자학에 대한 비판을 통해 다양한 학문을 수용...
#      처리시간: 2.07초
#   ❌ 문제 5: 예측=3, 정답=5, 점수=0/3
#      응답: 정답: 3번
#
# 해설: (가)와 (나)에서 언급된 유서들은 각각 실학자들의 현실 개혁 의도와 서양 학문의 수용을 다루고 있습니다. 3번 선택지는 "당대 지식을 망라하고 서양 관련 지...
#      처리시간: 2.40초
#   ✅ 문제 6: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 ⓑ : 계몽(啓蒙)하는
#
# 이유: 지문에서 ⓑ는 "이어받는"이라는 의미로 사용되고 있으며, 이는 기존의 주자학 지식을 수용하고 발전시키는 것을 나타냅니다. "계몽하는"은...
#      처리시간: 2.32초
#    지문 완료 - 현재 총점: 15점
#
# 🔍 진행률: 3/11 지문
#
# 📖 지문 ID: 2023_11_KICE_10-13
#    지문 길이: 1192자, 문제 수: 4
# --------------------------------------------------
#   ❌ 문제 1: 예측=1, 정답=4, 점수=0/2
#      응답: 정답: 1번 법령의 요건과 효과에는 모두 불확정 개념이 사용될 수 있다.
#
# 이유: 지문에서는 법령의 조문이 대개 조건문으로 구성되며, 불확정 개념이 사용될 수 있지만, 모든 요건과...
#      처리시간: 2.18초
#   ❌ 문제 2: 예측=4, 정답=5, 점수=0/2
#      응답: 정답: 4번 재량 준칙이 정해져야 행정청은 특정 요건하에 행정 작용의 구체적 내용을 선택할 수 있는 재량을 행사할 수 있다.
#      처리시간: 1.69초
#   ❌ 문제 3: 예측=1, 정답=2, 점수=0/3
#      응답: 정답: 3번
#
# 이유:
# - (가) 상황에서는 위약금 약정이 없으므로, 을은 손해를 입었더라도 갑에게 80을 지급받을 수 없습니다. 따라서 1번은 틀립니다.
# - (나) 상황에서는 위약...
#      처리시간: 4.27초
#   ❌ 문제 4: 예측=1, 정답=5, 점수=0/2
#      응답: 정답: 1번 이것이 네가 찾는 자료가 ⓐ(맞는지) 확인해 보아라.
#      처리시간: 1.36초
#    지문 완료 - 현재 총점: 15점
#
# 🔍 진행률: 4/11 지문
#
# 📖 지문 ID: 2023_11_KICE_14-17
#    지문 길이: 1810자, 문제 수: 4
# --------------------------------------------------
#   ❌ 문제 1: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번
#
# 이유: 'L-그래프'에서 직선의 기울기는 두 변수의 증가율의 차이를 나타내는 것이 아니라, 두 변수의 증가율이 같을 때 기울기가 1이 되며, 기초 대사량의 증가율이 ...
#      처리시간: 2.22초
#   ❌ 문제 2: 예측=1, 정답=4, 점수=0/2
#      응답: 정답: 3번
#
# 이유: 지문에서는 19세기 초기 연구자들이 체외로 발산되는 열량이 체표 면적에 비례한다고 보았다고 명시되어 있습니다. 따라서 그들은 체중의 증가율보다 기초 대사량의 ...
#      처리시간: 2.73초
#   ❌ 문제 3: 예측=3, 정답=4, 점수=0/2
#      응답: 정답: 3번
#
# 해설:
# ㉠은 직접법으로 기초 대사량을 측정하는 방법으로, 동물이 편하게 쉬는 상태에서 체외로 발산하는 열량을 측정합니다. 반면 ㉡은 간접법으로, 동물의 호흡을 통해...
#      처리시간: 7.89초
#   ✅ 문제 4: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번
#
# 이유: 지문에 따르면, L-그래프에서 최적의 직선의 기울기가 1보다 작다면 ⓐ(게딱지 폭)에 ⓑ(큰 집게발의 길이)가 비례한다고 할 수 없다는 내용이 있습니다. 기울...
#      처리시간: 2.40초
#    지문 완료 - 현재 총점: 18점
#
# 🔍 진행률: 5/11 지문
#
# 📖 지문 ID: 2023_11_KICE_18-21
#    지문 길이: 1934자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 감각적인 배경 묘사를 통해 인물의 행동이 전개되는 상황의 낭만적 분위기를 부각하고 있다.
#
# 이 선택지는 지문에서 최척과 옥영이 함께하는 장면의 배경 묘사가 매우 감각...
#      처리시간: 2.73초
#   ✅ 문제 2: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ‘최척’은 옥영의 시에 대한 재능을 결혼 전에 알고 있었지만, 옥영이 시를 읊기 전까지 이를 모른 척했다.
#
# 이유: 지문에서 최척은 옥영이 시를 잘 읊는 줄 몰랐다고 ...
#      처리시간: 2.35초
#   ❌ 문제 3: 예측=4, 정답=3, 점수=0/2
#      응답: 정답: 4번
#
# 해설:
# - ㉠(매월 초하루)는 최척 부부가 후사를 염려하여 기도를 올리는 행위를 나타내며, 이는 그들의 소망이 시작되는 시점입니다.
# - ㉡(정월 초하루)는 그 행위...
#      처리시간: 2.32초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번 최척과 옥영이 ‘소리를 지르며 끌어안’는 것은 문제의 해결에 따른 기쁨과, ‘눈물이 다하자 피가 흘러내’리는 것은 또 다른 문제 확인에 따른 인물의 불안감과 관련이 있...
#      처리시간: 2.08초
#    지문 완료 - 현재 총점: 25점
#
# 🔍 진행률: 6/11 지문
#
# 📖 지문 ID: 2023_11_KICE_22-26
#    지문 길이: 1747자, 문제 수: 5
# --------------------------------------------------
#   ❌ 문제 1: 예측=3, 정답=1, 점수=0/2
#      응답: 정답: 3번 현실을 통찰하며 관용적 삶에 대한 지향을 보여 주고 있다.
#
# 이유: (가)에서 이황은 자연과의 조화로운 삶을 추구하며, (나)에서 김득연은 자연의 아름다움과 그 속에...
#      처리시간: 2.92초
#   ❌ 문제 2: 예측=1, 정답=5, 점수=0/2
#      응답: 정답: 2번
#
# 이유: [A]의 <제2수> 초장은 <제1수> 종장의 시상을 이어받지 않고, 오히려 새로운 시상을 제시하고 있습니다. <제1수>는 자연과의 조화로운 관계를 강조하고 있...
#      처리시간: 2.36초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/3
#      응답: 정답: 3번
#
# 해설:
# 1번은 (가)의 '초야우생'이 화자가 자연과 조화롭게 살아가는 존재임을 나타내므로 적절합니다.
# 2번은 (나)의 '내 혼자 알았노라'가 자연의 가치를 발견한 ...
#      처리시간: 2.16초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ㉠은 화자에게 만족하며 머무르는 삶에 대해, ㉡은 글쓴이에게 허전하지 않은 이유에 대해 생각하게 한다.
#
# 이유: ㉠은 화자가 만든 작은 정자로, 그곳에서의 삶의 만족...
#      처리시간: 4.24초
#   ✅ 문제 5: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#
# 이유: 4번의 선택지는 "대상을 회화의 구도상 의미를 지닌 자리로 옮겨 풍경의 원근감을 보이는 그대로 실현해야 한다는 의미"라고 해석하고 있습니다. 그러나 [C]의 ...
#      처리시간: 3.59초
#    지문 완료 - 현재 총점: 29점
#
# 🔍 진행률: 7/11 지문
#
# 📖 지문 ID: 2023_11_KICE_27-30
#    지문 길이: 2441자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 ‘영익’은 가족의 상황을 알고서도 제 생각을 분명히 드러내지 않는다.
#
# 이 선택지는 영익이의 행동과 감정을 잘 반영하고 있습니다. 그는 이사 날짜가 결정되었다는 말을...
#      처리시간: 2.36초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#
# 설명: [E]의 서술 방식에서는 대화 상황에서 누가 말을 했는지 명시하지 않고, 대화의 흐름을 서술하고 있습니다. 그러나 이 경우, 대화의 주체는 어머니와 화자(서술...
#      처리시간: 2.19초
#   ❌ 문제 3: 예측=3, 정답=1, 점수=0/2
#      응답: 정답: 3번 ‘어머니’가 결혼 후에 심고 정성을 다해 키워 내어 무성해진 애착의 결실이다.
#
# 이 선택지는 지문에서 오동나무가 '어머니'와의 관계를 통해 자라난 과정을 잘 설명하고 ...
#      처리시간: 1.92초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2번
#
# 이유: 2번 선택지는 "집을 고치던 경험을 바탕으로 '구조'가 '천박'한 집의 여건을 살펴보는 것에서, 거주 환경의 변화에 적응하여 낯선 공간에 친숙해지고자 하는 '...
#      처리시간: 2.32초
#    지문 완료 - 현재 총점: 36점
#
# 🔍 진행률: 8/11 지문
#
# 📖 지문 ID: 2023_11_KICE_31-34
#    지문 길이: 785자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 사물의 모습에 대한 긍정적 인식을 바탕으로 중심 제재에 대한 예찬적 태도를 드러내고 있다.
#
# (가)와 (나) 모두 자연의 모습과 그 속에서의 생명에 대한 긍정적인 시...
#      처리시간: 2.08초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#
# 이유: ㉣에서 '극진한 축복과 은혜'는 사물의 인격화를 통해 표현된 것이 아니라, 자연의 현상이나 존재들이 주는 긍정적인 영향을 강조하는 부분입니다. 따라서 '화자의...
#      처리시간: 2.22초
#   ✅ 문제 3: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 [B]에서 참나무의 상태에 변화를 가져온 움직임은, [C]에서 버섯이 피어나는 상황과 순차적 관계를 형성한다.
#
# 이 선택지는 [B]에서 바람이 참나무를 흔들어 주고,...
#      처리시간: 2.15초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=3/3
#      응답: 정답: 3번
#
# 해설: (가)에서는 '넌출'이 만물의 조화로운 성장과 자족을 나타내고 있으며, (나)에서는 '홀씨'가 상처를 통해 생명체들이 흩어지는 계기를 나타내고 있습니다. 따라...
#      처리시간: 2.96초
#    지문 완료 - 현재 총점: 45점
#
# 🔍 진행률: 9/11 지문
#
# 📖 지문 ID: 2023_11_KICE_35-37
#    지문 길이: 1039자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 용어의 개념을 정의하여 발표에서 다룰 화제의 범위를 한정하고 있다.
#
# 이유: 발표자는 도로 안전 설계에 대한 내용을 다루고 있으며, 청중의 경험을 공유하고 질문을 통...
#      처리시간: 2.34초
#   ❌ 문제 2: 예측=3, 정답=5, 점수=0/2
#      응답: 정답: 5번 [자료3]은 달라지는 밝기에 눈이 서서히 적응하도록 조명등의 설치 간격을 달리한다는 내용을 설명하기 위해 ㉢에서 활용하였다.
#      처리시간: 3.31초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번 학생 1과 학생 2는 모두, 발표에서 언급된 내용과 관련하여 추가적인 정보를 탐색하려 하고 있다.
#
# 학생 1은 곡선 도로에 경사를 주는 원리를 알아보겠다고 하였고, ...
#      처리시간: 2.23초
#    지문 완료 - 현재 총점: 47점
#
# 🔍 진행률: 10/11 지문
#
# 📖 지문 ID: 2023_11_KICE_38-42
#    지문 길이: 2367자, 문제 수: 5
# --------------------------------------------------
#   ❌ 문제 1: 예측=2, 정답=4, 점수=0/2
#      응답: 정답: 2번 2문단에서는 식물 지도를 만든 과정을 원인과 결과를 제시하는 방식으로 서술하였다.
#      처리시간: 1.35초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 교실 밖에서 관찰 활동을 하려면 책을 활용한 학습이 선행될 필요가 있다는 내용을 추가하는 게 어때?
#
# 이 선택지는 (가)의 마지막 문단에서 언급된 내용과 관련이 없으...
#      처리시간: 2.55초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번
#
# 이유: [B]에서 ‘학생 1’과 ‘학생 3’은 서로의 발화 내용을 잘못 이해했음을 깨닫고 있지 않습니다. ‘학생 1’은 ‘학생 3’의 발화 내용을 잘못 이해한 것이 ...
#      처리시간: 2.39초
#   ❌ 문제 4: 예측=1, 정답=2, 점수=0/3
#      응답: 정답: 3번 달리할 점 : 조사 인원을 고려하여, 우리는 학교에서 걸어갈 만큼 가까운 거리만 지도의 범위로 삼는다.
#
# 이유: (가)에서 ○○ 고등학교는 넓은 지역을 조사하여 식물 ...
#      처리시간: 2.91초
#   ❌ 문제 5: 예측=1, 정답=4, 점수=0/2
#      응답: 정답: 1번 ㉠ : 식물이 있는 곳의 핵심적인 특징을 제시하기로 했으므로 논의한 내용이 반영되었군.
#      처리시간: 1.73초
#    지문 완료 - 현재 총점: 49점
#
# 🔍 진행률: 11/11 지문
#
# 📖 지문 ID: 2023_11_KICE_43-45
#    지문 길이: 819자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 ㉤
#
# 이유: 지문에서는 커피로 인해 발생하는 사회적 문제가 해마다 증가하고 있다는 실태에 대한 언급이 없습니다. 다른 선택지들은 지문에서 다루어진 내용과 관련이 있으며...
#      처리시간: 2.99초
#   ✅ 문제 2: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 커피박의 올바른 처리 방법과 재활용 분야를 홍보하고, 수거 시설 확충을 제도화할 필요가 있다. 커피박에도 관심을 갖는 책임감 있는 태도가 커피 사랑의 참된 자세이다.
#      처리시간: 2.34초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번 (가)
#
# 이유: 1번 선택지는 커피박을 소각할 때 발생하는 탄소 배출량 수치를 커피박이 우리 사회에서 관심을 받지 못하고 있는 배경을 보여주는 자료로 1문단에 추가하...
#      처리시간: 2.76초
#    지문 완료 - 현재 총점: 56점
#
# ============================================================
# ✅ 테스트 완료: emotional_appeal + gpt-4o-mini
# ⏰ 완료 시간: 2025-05-25 17:46:23
# 📊 최종 결과:
#    총점: 56/100점 (56.0%)
#    정답률: 55.6% (25/45)
#    소요시간: 140.15초
# ============================================================
# ✅ 조합 2 완료
#
# ------------------------------------------------------------
#
# 🚀 테스트 조합 3/6: gpt-4o-mini + expert_role
#
# ============================================================
# 🚀 테스트 시작: gpt-4o-mini + expert_role
# ⏰ 시작 시간: 2025-05-25 17:46:23
# ============================================================
#
# 🔍 진행률: 1/11 지문
#
# 📖 지문 ID: 2023_11_KICE_1-3
#    지문 길이: 978자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#
# 해설: 지문에서는 독자의 배경지식, 관점, 읽기 환경, 과제 등이 독자의 의미 구성에 영향을 미친다고 언급하고 있지만, 이를 '독자 요인'으로 명시적으로 구분하지는 ...
#      처리시간: 2.41초
#   ❌ 문제 2: 예측=4, 정답=5, 점수=0/3
#      응답: 정답: 4번
#
# 해설:
# - ⓐ는 "음악 시간에 들었던 베토벤의 교향곡 <합창>이 위대한 작품인 이유는 무엇일까?"라는 질문으로, 이는 독자가 책에서 답을 찾으려는 질문입니다.
# - ⓑ...
#      처리시간: 2.96초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#
# 해설: ㉠은 "다른 독자와 소통하는 즐거움을 경험할 수도 있다."라는 내용과 관련이 있습니다. 1번 선택지는 "스스로 독서 계획을 세우고 자신에게 필요한 책을 찾아 ...
#      처리시간: 2.99초
#    지문 완료 - 현재 총점: 4점
#
# 🔍 진행률: 2/11 지문
#
# 📖 지문 ID: 2023_11_KICE_4-9
#    지문 길이: 2158자, 문제 수: 6
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 (가)는 유서의 특성과 의의를 설명하였고, (나)는 유서 편찬에서 특정 학문의 수용 양상을 시기별로 소개하였다.
#      처리시간: 1.64초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#
# 이유: 지문에서는 유서가 기존 서적에서 필요한 부분을 뽑아 배열할 뿐 상호 비교하거나 편찬자의 해석을 가하지 않았다고 명시되어 있습니다. 따라서 5번의 내용은 지문과...
#      처리시간: 1.83초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번
#
# 해설:
# 문제에서 ㉮는 실학자들의 유서 편찬 의도를 설명하고 있으며, 지식의 제공과 확산, 지식의 재분류 및 평가를 강조하고 있습니다.
#
# 1번은 ㉠에서 지식을 심화...
#      처리시간: 3.14초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 주자학에 매몰되어 세상의 여러 이치를 연구하지 않는 것은 널리 배우고 익히는 앎의 바른 방법이 아닐 것이다.
#
# 이수광은 주자학에 국한되지 않고 다양한 지식을 수용하고...
#      처리시간: 2.89초
#   ✅ 문제 5: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번
#
# 해설: 5번 선택지는 "중국을 문명의 척도로 받아들였던 (나)의 오주연문장전산고와 달리 중화 관념에 구애되지 않고 중국의 현실과 조선의 현실을 비교한 내용이 확인되겠...
#      처리시간: 2.44초
#   ✅ 문제 6: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 ⓑ : 계몽(啓蒙)하는
#
# 이유: 문맥상 ⓑ는 "이어받는"이라는 의미로 사용되고 있으며, "계몽하는"은 그 의미와 맞지 않습니다. "계몽하는"은 지식을 주거나 가르치는 ...
#      처리시간: 2.16초
#    지문 완료 - 현재 총점: 15점
#
# 🔍 진행률: 3/11 지문
#
# 📖 지문 ID: 2023_11_KICE_10-13
#    지문 길이: 1192자, 문제 수: 4
# --------------------------------------------------
#   ❌ 문제 1: 예측=1, 정답=4, 점수=0/2
#      응답: 정답: 1번 법령의 요건과 효과에는 모두 불확정 개념이 사용될 수 있다.
#
# 해설: 지문에서는 법령의 조문이 'A에 해당하면 B를 해야 한다.'와 같은 조건문으로 구성되며, 불확정...
#      처리시간: 3.22초
#   ❌ 문제 2: 예측=1, 정답=5, 점수=0/2
#      응답: 정답: 1번 재량 준칙은 법령이 아니기 때문에 일의적이지 않은 개념으로 규정된다.
#      처리시간: 1.16초
#   ❌ 문제 3: 예측=1, 정답=2, 점수=0/3
#      응답: 정답: 3번
#
# **해설:**
#
# - (가) 상황에서는 위약금 약정이 없으므로, 을은 손해를 입었더라도 갑에게 80을 지급받을 수 있습니다. 그러나 법원이 감액할 수 없다는 내용은 맞...
#      처리시간: 2.98초
#   ❌ 문제 4: 예측=1, 정답=5, 점수=0/2
#      응답: 정답: 1번 이것이 네가 찾는 자료가 ⓐ(맞는지) 확인해 보아라.
#      처리시간: 1.08초
#    지문 완료 - 현재 총점: 15점
#
# 🔍 진행률: 4/11 지문
#
# 📖 지문 ID: 2023_11_KICE_14-17
#    지문 길이: 1810자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#
# 해설:
# 3번 선택지는 "‘L-그래프’에서 직선의 기울기는 가로축과 세로축 두 변수의 증가율의 차이와 동일하다."라고 되어 있는데, 이는 잘못된 설명입니다. L-그래...
#      처리시간: 2.84초
#   ❌ 문제 2: 예측=1, 정답=4, 점수=0/2
#      응답: 정답: 3번
#
# 해설:
# 1번은 기초 대사량이 하루에 소모되는 총 열량 중 가장 큰 비중을 차지한다고 설명하고 있으며, 이는 지문에서 언급된 내용과 일치합니다.
# 2번은 클라이버의 결...
#      처리시간: 57.16초
#   ❌ 문제 3: 예측=3, 정답=4, 점수=0/2
#      응답: 정답: 3번 ㉠은 ㉡과 달리 격한 움직임이 제한된 편하게 쉬는 상태에서 기초 대사량을 구한다.
#
# 이유: ㉠은 직접법으로 기초 대사량을 측정하는 방법으로, 동물이 편히 쉬는 상태에...
#      처리시간: 2.32초
#   ✅ 문제 4: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번
#
# 해설:
# 1번 선택지는 "최적의 직선의 기울기가 1보다 작다면 ⓐ에 ⓑ가 비례한다고 할 수 없겠군."이라고 하였는데, 이는 맞는 설명입니다. 기울기가 1보다 작다는 것...
#      처리시간: 2.84초
#    지문 완료 - 현재 총점: 20점
#
# 🔍 진행률: 5/11 지문
#
# 📖 지문 ID: 2023_11_KICE_18-21
#    지문 길이: 1934자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 감각적인 배경 묘사를 통해 인물의 행동이 전개되는 상황의 낭만적 분위기를 부각하고 있다.
#
# 이 지문에서는 최척과 옥영의 감정과 행동이 자연의 아름다움과 함께 묘사되며...
#      처리시간: 2.92초
#   ✅ 문제 2: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ‘최척’은 옥영의 시에 대한 재능을 결혼 전에 알고 있었지만, 옥영이 시를 읊기 전까지 이를 모른 척했다.
#
# 이유: 지문에서는 최척이 옥영이 시를 잘 읊는 줄 몰랐다고...
#      처리시간: 3.17초
#   ❌ 문제 3: 예측=4, 정답=3, 점수=0/2
#      응답: 정답: 4번
#
# 해설:
# - ㉠(매월 초하루)는 최척 부부가 후사를 염려하여 만복사에 기도를 올리는 행위를 시작하는 시점으로, 이들은 자식에 대한 소망을 가지고 기도를 하게 됩니다....
#      처리시간: 3.53초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번 최척과 옥영이 ‘소리를 지르며 끌어안’는 것은 문제의 해결에 따른 기쁨과, ‘눈물이 다하자 피가 흘러내’리는 것은 또 다른 문제 확인에 따른 인물의 불안감과 관련이 있...
#      처리시간: 2.44초
#    지문 완료 - 현재 총점: 27점
#
# 🔍 진행률: 6/11 지문
#
# 📖 지문 ID: 2023_11_KICE_22-26
#    지문 길이: 1747자, 문제 수: 5
# --------------------------------------------------
#   ❌ 문제 1: 예측=3, 정답=1, 점수=0/2
#      응답: 정답: 3번 현실을 통찰하며 관용적 삶에 대한 지향을 보여 주고 있다.
#
# 이유: (가)에서 이황은 자연과의 조화로운 삶을 추구하며, (나)에서 김득연은 자연의 아름다움과 그 속에...
#      처리시간: 2.28초
#   ❌ 문제 2: 예측=1, 정답=5, 점수=0/2
#      응답: 정답: 2번
#
# 해설:
# 1번은 [A]의 <제1수> 초장이 유사한 어휘의 반복을 통해 리듬감을 형성하고 있다는 설명이 적절합니다.
# 2번은 [A]의 <제2수> 초장이 <제1수> 종장의 ...
#      처리시간: 2.35초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/3
#      응답: 정답: 4번
#
# 해설:
# - 1번은 (가)의 '초야우생'이 화자가 자연과 조화롭게 살아가는 존재임을 나타내므로 적절합니다.
# - 2번은 (나)의 '내 혼자 알았노라'가 자연의 가치를 ...
#      처리시간: 2.66초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ㉠은 화자에게 만족하며 머무르는 삶에 대해, ㉡은 글쓴이에게 허전하지 않은 이유에 대해 생각하게 한다.
#
# 이유: ㉠은 화자가 만든 작은 정자로, 그곳에서의 삶의 만족...
#      처리시간: 2.57초
#   ✅ 문제 5: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#
# 해설: 4번의 선택지는 "대상을 회화의 구도상 의미를 지닌 자리로 옮겨 풍경의 원근감을 보이는 그대로 실현해야 한다는 의미"라고 해석하고 있습니다. 그러나 [C]의 ...
#      처리시간: 2.59초
#    지문 완료 - 현재 총점: 31점
#
# 🔍 진행률: 7/11 지문
#
# 📖 지문 ID: 2023_11_KICE_27-30
#    지문 길이: 2441자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 ‘영익’은 가족의 상황을 알고서도 제 생각을 분명히 드러내지 않는다.
#
# 이유: 지문에서 영익이는 집에 내려와 이사 날짜가 결정되었다는 말을 듣고 아무 말도 없이 고개...
#      처리시간: 2.72초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#
# 해설: [E]의 서술 방식에서는 대화가 이루어지고 있지만, 누가 한 말인지 명시하지 않고 있습니다. 그러나 대화의 맥락상 어머니가 대화의 주체임을 알 수 있으며, 서...
#      처리시간: 2.47초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 ‘나’가 계절의 자연스러운 변화와 세월의 흐름을 느끼게 되는 경험적 대상이다.
#
# 이유: 지문에서 오동나무는 '나'의 성장과 함께 자라며, 계절의 변화와 함께 그 모습...
#      처리시간: 2.25초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2번
#
# 이유: 2번 선택지는 '집을 고치'던 경험을 바탕으로 '구조'가 '천박'한 집의 여건을 살펴보는 것에서, 거주 환경의 변화에 적응하여 낯선 공간에 친숙해지고자 하는 ...
#      처리시간: 2.30초
#    지문 완료 - 현재 총점: 40점
#
# 🔍 진행률: 8/11 지문
#
# 📖 지문 ID: 2023_11_KICE_31-34
#    지문 길이: 785자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 사물의 모습에 대한 긍정적 인식을 바탕으로 중심 제재에 대한 예찬적 태도를 드러내고 있다.
#
# 분석: (가)에서는 여름 채전의 풍경을 통해 자연의 아름다움과 그 속에서...
#      처리시간: 2.28초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#
# 해설: 4번 선택지는 ㉣에서 사물을 인격화하여 ‘극진한 축복과 은혜’와 대비되는 화자의 시선을 반영하고 있다고 설명하고 있지만, 실제로 ㉣은 '많은 손님들'을 언급하...
#      처리시간: 2.33초
#   ❌ 문제 3: 예측=1, 정답=2, 점수=0/2
#      응답: 정답: 1번
#
# 해설:
# [A]에서 참나무가 벌목으로 썩어 가는 모습은, [B]에서 바람에 흔들리는 나무의 모습과 순환적 관계를 형성합니다. 참나무가 썩어가는 과정은 자연의 순환 속...
#      처리시간: 2.22초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=3/3
#      응답: 정답: 3번
#
# 해설: (가)와 (나)의 내용을 분석해보면, (가)는 생명체들이 조화롭게 성장하고 충만한 생명력을 자족하는 모습을 보여주고 있으며, (나)는 인간의 욕망으로 인해 상...
#      처리시간: 2.00초
#    지문 완료 - 현재 총점: 47점
#
# 🔍 진행률: 9/11 지문
#
# 📖 지문 ID: 2023_11_KICE_35-37
#    지문 길이: 1039자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 용어의 개념을 정의하여 발표에서 다룰 화제의 범위를 한정하고 있다.
#
# 이유: 발표자는 특정 용어의 개념을 정의하는 방식보다는 청중의 경험을 공유하고, 질문을 통해 반...
#      처리시간: 3.23초
#   ❌ 문제 2: 예측=3, 정답=5, 점수=0/2
#      응답: 정답: 5번 [자료3]은 달라지는 밝기에 눈이 서서히 적응하도록 조명등의 설치 간격을 달리한다는 내용을 설명하기 위해 ㉢에서 활용하였다.
#
# 이유: 발표 내용에서 터널의 조명등 설...
#      처리시간: 2.95초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번 학생 1과 학생 2는 모두, 발표에서 언급된 내용과 관련하여 추가적인 정보를 탐색하려 하고 있다.
#
# 해설:
# - 학생 1은 곡선 도로에 경사를 주는 원리를 알아보겠다...
#      처리시간: 2.16초
#    지문 완료 - 현재 총점: 49점
#
# 🔍 진행률: 10/11 지문
#
# 📖 지문 ID: 2023_11_KICE_38-42
#    지문 길이: 2367자, 문제 수: 5
# --------------------------------------------------
#   ❌ 문제 1: 예측=2, 정답=4, 점수=0/2
#      응답: 정답: 2번 2문단에서는 식물 지도를 만든 과정을 원인과 결과를 제시하는 방식으로 서술하였다.
#      처리시간: 1.86초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 교실 밖에서 관찰 활동을 하려면 책을 활용한 학습이 선행될 필요가 있다는 내용을 추가하는 게 어때?
#
# 이유: (가)의 마지막 문단에서는 교실 밖에서의 관찰 활동이 학...
#      처리시간: 2.78초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번
#
# 해설:
# - 1번: [A]에서 ‘학생 2’는 ‘학생 1’의 발화를 재진술한 후 자신의 의견을 밝히고 있으므로 적절한 설명이다.
# - 2번: [A]에서 ‘학생 1’은 ‘학...
#      처리시간: 2.56초
#   ❌ 문제 4: 예측=1, 정답=2, 점수=0/3
#      응답: 정답: 5번 달리할 점 : 지도의 통일감을 고려하여, 우리는 각각의 지도를 이어 붙이는 방식은 활용하지 않는다.
#
# 이유: (가)에서 ○○ 고등학교는 학급별로 만든 지도를 이어 붙여...
#      처리시간: 2.74초
#   ❌ 문제 5: 예측=1, 정답=4, 점수=0/2
#      응답: 정답: 1번 ㉠ : 식물이 있는 곳의 핵심적인 특징을 제시하기로 했으므로 논의한 내용이 반영되었군
#      처리시간: 1.08초
#    지문 완료 - 현재 총점: 51점
#
# 🔍 진행률: 11/11 지문
#
# 📖 지문 ID: 2023_11_KICE_43-45
#    지문 길이: 819자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 ㉤
#
# 분석: 지문에서는 커피박에 대한 다양한 정보와 사회적 문제를 다루고 있지만, 커피로 인해 발생하는 사회적 문제가 해마다 증가하고 있는 실태에 대한 언급은 없습니다...
#      처리시간: 2.40초
#   ✅ 문제 2: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 커피박의 올바른 처리 방법과 재활용 분야를 홍보하고, 수거 시설 확충을 제도화할 필요가 있다. 커피박에도 관심을 갖는 책임감 있는 태도가 커피 사랑의 참된 자세이다. ...
#      처리시간: 2.64초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번 (가)
#
# 이유: 1번 선택지는 커피박을 소각할 때 발생하는 탄소 배출량 수치를 1문단에 추가하는 방안으로, 커피박이 우리 사회에서 관심을 받지 못하고 있는 배경을 보...
#      처리시간: 3.14초
#    지문 완료 - 현재 총점: 58점
#
# ============================================================
# ✅ 테스트 완료: expert_role + gpt-4o-mini
# ⏰ 완료 시간: 2025-05-25 17:49:33
# 📊 최종 결과:
#    총점: 58/100점 (58.0%)
#    정답률: 57.8% (26/45)
#    소요시간: 189.41초
# ============================================================
# ✅ 조합 3 완료
#
# ------------------------------------------------------------
#
# 🚀 테스트 조합 4/6: gpt-4o + zero_shot
#
# ============================================================
# 🚀 테스트 시작: gpt-4o + zero_shot
# ⏰ 시작 시간: 2025-05-25 17:49:33
# ============================================================
#
# 🔍 진행률: 1/11 지문
#
# 📖 지문 ID: 2023_11_KICE_1-3
#    지문 길이: 978자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 1.05초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번
#      처리시간: 0.72초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 0.85초
#    지문 완료 - 현재 총점: 7점
#
# 🔍 진행률: 2/11 지문
#
# 📖 지문 ID: 2023_11_KICE_4-9
#    지문 길이: 2158자, 문제 수: 6
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 0.68초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#      처리시간: 0.97초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 1.13초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번
#      처리시간: 0.55초
#   ✅ 문제 5: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번
#      처리시간: 0.97초
#   ✅ 문제 6: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 ⓑ : 계몽(啓蒙)하는
#      처리시간: 0.66초
#    지문 완료 - 현재 총점: 20점
#
# 🔍 진행률: 3/11 지문
#
# 📖 지문 ID: 2023_11_KICE_10-13
#    지문 길이: 1192자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 0.73초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#      처리시간: 0.50초
#   ✅ 문제 3: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2번
#      처리시간: 0.73초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#      처리시간: 0.55초
#    지문 완료 - 현재 총점: 29점
#
# 🔍 진행률: 4/11 지문
#
# 📖 지문 ID: 2023_11_KICE_14-17
#    지문 길이: 1810자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 1.17초
#   ❌ 문제 2: 예측=5, 정답=4, 점수=0/2
#      응답: 정답: 5번
#      처리시간: 1.43초
#   ❌ 문제 3: 예측=5, 정답=4, 점수=0/2
#      응답: 정답: 5번
#      처리시간: 1.08초
#   ✅ 문제 4: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번
#      처리시간: 1.23초
#    지문 완료 - 현재 총점: 34점
#
# 🔍 진행률: 5/11 지문
#
# 📖 지문 ID: 2023_11_KICE_18-21
#    지문 길이: 1934자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 1.32초
#   ✅ 문제 2: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 1.14초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 1.01초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번
#      처리시간: 1.24초
#    지문 완료 - 현재 총점: 43점
#
# 🔍 진행률: 6/11 지문
#
# 📖 지문 ID: 2023_11_KICE_22-26
#    지문 길이: 1747자, 문제 수: 5
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 0.98초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#      처리시간: 1.11초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=3/3
#      응답: 정답: 3번
#      처리시간: 1.03초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 1.02초
#   ✅ 문제 5: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 0.88초
#    지문 완료 - 현재 총점: 54점
#
# 🔍 진행률: 7/11 지문
#
# 📖 지문 ID: 2023_11_KICE_27-30
#    지문 길이: 2441자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 3.40초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#      처리시간: 1.17초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 1.01초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2번
#      처리시간: 0.96초
#    지문 완료 - 현재 총점: 63점
#
# 🔍 진행률: 8/11 지문
#
# 📖 지문 ID: 2023_11_KICE_31-34
#    지문 길이: 785자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 2.03초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 30.61초
#   ✅ 문제 3: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번
#      처리시간: 0.98초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=3/3
#      응답: 정답: 3번
#      처리시간: 1.26초
#    지문 완료 - 현재 총점: 72점
#
# 🔍 진행률: 9/11 지문
#
# 📖 지문 ID: 2023_11_KICE_35-37
#    지문 길이: 1039자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#      처리시간: 0.97초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#      처리시간: 0.93초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 0.51초
#    지문 완료 - 현재 총점: 78점
#
# 🔍 진행률: 10/11 지문
#
# 📖 지문 ID: 2023_11_KICE_38-42
#    지문 길이: 2367자, 문제 수: 5
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 0.72초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#      처리시간: 1.04초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#      처리시간: 0.84초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2번
#      처리시간: 0.61초
#   ✅ 문제 5: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 ㉣ : 각 장소마다 하나씩 대표 식물의 사진을 제시하기로 했으므로 사진을 추가해야겠군.
#      처리시간: 0.99초
#    지문 완료 - 현재 총점: 89점
#
# 🔍 진행률: 11/11 지문
#
# 📖 지문 ID: 2023_11_KICE_43-45
#    지문 길이: 819자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 ㉤
#      처리시간: 0.57초
#   ✅ 문제 2: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번
#      처리시간: 0.63초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번
#      처리시간: 0.62초
#    지문 완료 - 현재 총점: 96점
#
# ============================================================
# ✅ 테스트 완료: zero_shot + gpt-4o
# ⏰ 완료 시간: 2025-05-25 17:51:10
# 📊 최종 결과:
#    총점: 96/100점 (96.0%)
#    정답률: 95.6% (43/45)
#    소요시간: 97.24초
# ============================================================
# ✅ 조합 4 완료
#
# ------------------------------------------------------------
#
# 🚀 테스트 조합 5/6: gpt-4o + emotional_appeal
#
# ============================================================
# 🚀 테스트 시작: gpt-4o + emotional_appeal
# ⏰ 시작 시간: 2025-05-25 17:51:10
# ============================================================
#
# 🔍 진행률: 1/11 지문
#
# 📖 지문 ID: 2023_11_KICE_1-3
#    지문 길이: 978자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 독자의 배경지식, 관점, 읽기 환경, 과제는 독자의 의미 구성에 영향을 주는 독자 요인이다.
#
# 지문에서는 독자의 배경지식이나 관점 등의 독자 요인과 읽기 환경이나 과...
#      처리시간: 3.13초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번 ⓓ에는 ‘독자 자신에게서 답을 찾는 질문’이, ⓔ에는 그에 대한 답을 ‘독자의 경험’에서 찾아내는 모습이 나타난다.
#      처리시간: 2.24초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번
#
# 1번 선택지는 개인적으로 책을 읽는 과정에서의 경험을 언급하고 있으며, 이는 ㉠에서 언급된 "다른 독자와 소통하는 즐거움"과는 관련이 없습니다. ㉠은 다른 독자와의 ...
#      처리시간: 2.10초
#    지문 완료 - 현재 총점: 7점
#
# 🔍 진행률: 2/11 지문
#
# 📖 지문 ID: 2023_11_KICE_4-9
#    지문 길이: 2158자, 문제 수: 6
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 (가)는 유서의 특성과 의의를 설명하였고, (나)는 유서 편찬에서 특정 학문의 수용 양상을 시기별로 소개하였다.
#      처리시간: 1.28초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 중국에서는 주로 서적에서 발췌한 내용을 비교하고 해석을 덧붙여 유서를 편찬하였다.
#      처리시간: 1.24초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번
#
# 3번 선택지는 ㉮의 "평가를 더하는 저술"의 성격을 ㉡에서 "중국 학문의 진보성을 확인하고자 서학을 활용한 것"과 연결하고 있습니다. 그러나 지문에서 ㉡에 해당하는 ...
#      처리시간: 1.98초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 주자학에 매몰되어 세상의 여러 이치를 연구하지 않는 것은 널리 배우고 익히는 앎의 바른 방법이 아닐 것이다.
#      처리시간: 1.54초
#   ✅ 문제 5: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번
#
# 5번 선택지는 "중국을 문명의 척도로 받아들였던 (나)의 오주연문장전산고와 달리 중화 관념에 구애되지 않고 중국의 현실과 조선의 현실을 비교한 내용이 확인되겠군."이...
#      처리시간: 1.94초
#   ✅ 문제 6: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 ⓑ : 계몽(啓蒙)하는
#
# 문맥상 ⓑ는 "이어받는"이라는 의미로, "계몽하는"으로 바꾸어 쓰기에는 적절하지 않습니다. "계몽하는"은 새로운 지식을 가르치거나 깨우치는 의...
#      처리시간: 1.95초
#    지문 완료 - 현재 총점: 20점
#
# 🔍 진행률: 3/11 지문
#
# 📖 지문 ID: 2023_11_KICE_10-13
#    지문 길이: 1192자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 불확정 개념이 사용된 행정 법령에 근거한 행정 작용은 재량 행위인 경우보다 기속 행위인 경우가 많다.
#
# 지문에서는 불확정 개념이 사용된 법령에 근거한 행정 작용은 대개...
#      처리시간: 7.14초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 재량 준칙이 특정 요건에서 적용된 선례가 없으면 행정청은 동일한 요건이 충족되어도 행정 작용을 할 때 재량 준칙을 따르지 않을 수 있다.
#      처리시간: 1.60초
#   ❌ 문제 3: 예측=1, 정답=2, 점수=0/3
#      응답: 정답: 2번 (나)에서 을의 손해가 80임이 증명된 경우, 갑이 을에게 100을 지급해야 하고 법원이 감액할 수 있다.
#
# 설명:
# - (가) 상황에서는 위약금 약정이 없으므로, 을...
#      처리시간: 1.98초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 그분은 우리에게 한 약속을 반드시 ⓔ(지킬) 것이다.
#      처리시간: 1.32초
#    지문 완료 - 현재 총점: 26점
#
# 🔍 진행률: 4/11 지문
#
# 📖 지문 ID: 2023_11_KICE_14-17
#    지문 길이: 1810자, 문제 수: 4
# --------------------------------------------------
#   ❌ 문제 1: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번 ‘L-그래프’에서 직선의 기울기는 가로축과 세로축 두 변수의 증가율의 차이와 동일하다.
#
# 지문에서는 L-그래프에서 직선의 기울기가 두 변수의 증가율을 비교할 수 있게 ...
#      처리시간: 2.13초
#   ❌ 문제 2: 예측=1, 정답=4, 점수=0/2
#      응답: 정답: 5번
#
# 지문에 따르면, 클라이버의 법칙에 의하면 기초 대사량은 (체중)^0.75에 비례한다고 결론지었습니다. 반면, 19세기의 초기 연구자들은 기초 대사량이 (체중)^0.6...
#      처리시간: 2.18초
#   ✅ 문제 3: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 ㉠과 ㉡은 모두 일정한 체온에서 동물이 체외로 발산하는 열량을 구할 수 있다.
#      처리시간: 1.59초
#   ✅ 문제 4: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번
#
# 지문에 따르면, L-그래프에서 두 변수의 증가율이 같다면 직선의 기울기는 1이 됩니다. 따라서, 최적의 직선의 기울기가 1보다 작다면 ⓐ에 ⓑ가 비례한다고 할 수 없...
#      처리시간: 1.95초
#    지문 완료 - 현재 총점: 31점
#
# 🔍 진행률: 5/11 지문
#
# 📖 지문 ID: 2023_11_KICE_18-21
#    지문 길이: 1934자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 감각적인 배경 묘사를 통해 인물의 행동이 전개되는 상황의 낭만적 분위기를 부각하고 있다.
#      처리시간: 1.41초
#   ✅ 문제 2: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ‘최척’은 옥영의 시에 대한 재능을 결혼 전에 알고 있었지만, 옥영이 시를 읊기 전까지 이를 모른 척했다.
#
# 지문에서는 최척이 옥영의 시 재능을 결혼 전에 알고 있었다...
#      처리시간: 2.26초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ㉣은 인물의 행위가 반복적으로 일어나는, ㉤은 ㉣ 중 한 시점을 특정하는 시간의 표지이다.
#      처리시간: 2.27초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번
#
# 5번 선택지는 최척과 옥영이 재회하는 장면에서의 감정 표현을 잘못 해석하고 있습니다. '소리를 지르며 끌어안'는 것은 문제 해결에 따른 기쁨을 나타내지만, '눈물이 ...
#      처리시간: 2.43초
#    지문 완료 - 현재 총점: 40점
#
# 🔍 진행률: 6/11 지문
#
# 📖 지문 ID: 2023_11_KICE_22-26
#    지문 길이: 1747자, 문제 수: 5
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 대상에 주목하여 대상과 관련된 가치를 추구하는 자세를 나타내고 있다.
#      처리시간: 1.43초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#
# 5번 선택지는 [A]의 ‘허물이나 없고자’가 미래에 대한 화자의 바람을 표현하고 있다는 점은 맞지만, [B]의 ‘티 없어’는 대상을 관찰하기 전에 나타난 화자의 심리...
#      처리시간: 3.36초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=3/3
#      응답: 정답: 3번 (가)의 ‘천석고황’은 이상적 공간에 다다르지 못한 것에 대한 화자의 아쉬움이, (나)의 ‘무릉도원’은 현실적 공간을 이상적 공간으로 바라보는 화자의 인식이 나타난 말...
#      처리시간: 1.99초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ㉠은 화자에게 만족하며 머무르는 삶에 대해, ㉡은 글쓴이에게 허전하지 않은 이유에 대해 생각하게 한다.
#      처리시간: 1.43초
#   ✅ 문제 5: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#
# 4번 선택지는 "대상을 회화의 구도상 의미를 지닌 자리로 옮겨 풍경의 원근감을 보이는 그대로 실현해야 한다는 의미"라고 해석하고 있습니다. 그러나 지문과 <보기>에서...
#      처리시간: 2.39초
#    지문 완료 - 현재 총점: 51점
#
# 🔍 진행률: 7/11 지문
#
# 📖 지문 ID: 2023_11_KICE_27-30
#    지문 길이: 2441자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 ‘영익’은 가족의 상황을 알고서도 제 생각을 분명히 드러내지 않는다.
#      처리시간: 1.43초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번
#
# 5번 선택지는 [E] 부분에서 누가 한 말인지 명시하지 않은 것을 근거로 대화 상황에서 말하는 이와 서술자가 다르다는 사실을 알 수 있다고 설명하고 있습니다. 그러나...
#      처리시간: 3.49초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 ‘나’가 계절의 자연스러운 변화와 세월의 흐름을 느끼게 되는 경험적 대상이다.
#      처리시간: 1.51초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2번 ‘집을 고치’던 경험을 바탕으로 ‘구조’가 ‘천박’한 집의 여건을 살펴보는 것에서, 거주 환경의 변화에 적응하여 낯선 공간에 친숙해지고자 하는 ‘나’의 생각을 확인할 ...
#      처리시간: 1.83초
#    지문 완료 - 현재 총점: 60점
#
# 🔍 진행률: 8/11 지문
#
# 📖 지문 ID: 2023_11_KICE_31-34
#    지문 길이: 785자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 사물의 모습에 대한 긍정적 인식을 바탕으로 중심 제재에 대한 예찬적 태도를 드러내고 있다.
#      처리시간: 1.76초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 ㉣에서 사물을 인격화하여 ‘극진한 축복과 은혜’와 대비되는 화자의 시선을 반영하고 있다.
#      처리시간: 9.29초
#   ✅ 문제 3: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 [B]에서 참나무의 상태에 변화를 가져온 움직임은, [C]에서 버섯이 피어나는 상황과 순차적 관계를 형성한다.
#      처리시간: 2.63초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=3/3
#      응답: 정답: 3번 (가)의 ‘넌출’은 어우러진 생명체들이 현실의 삶에 자족하게 되는, (나)의 ‘홀씨’는 공존하던 생명체들이 흩어지게 되는 계기를 드러내고 있군.
#
# (가)에서 '넌출'...
#      처리시간: 2.26초
#    지문 완료 - 현재 총점: 69점
#
# 🔍 진행률: 9/11 지문
#
# 📖 지문 ID: 2023_11_KICE_35-37
#    지문 길이: 1039자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 용어의 개념을 정의하여 발표에서 다룰 화제의 범위를 한정 하고 있다.
#      처리시간: 1.28초
#   ❌ 문제 2: 예측=3, 정답=5, 점수=0/2
#      응답: 정답: 5번 [자료3]은 달라지는 밝기에 눈이 서서히 적응하도록 조명등의 설치 간격을 달리한다는 내용을 설명하기 위해 ㉢에서 활용하였다.
#      처리시간: 2.52초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번 학생 1과 학생 2는 모두, 발표에서 언급된 내용과 관련하여 추가적인 정보를 탐색하려 하고 있다.
#      처리시간: 1.29초
#    지문 완료 - 현재 총점: 71점
#
# 🔍 진행률: 10/11 지문
#
# 📖 지문 ID: 2023_11_KICE_38-42
#    지문 길이: 2367자, 문제 수: 5
# --------------------------------------------------
#   ❌ 문제 1: 예측=3, 정답=4, 점수=0/2
#      응답: 정답: 4번 3문단에서는 식물 조사에 임하는 자신의 참여 자세를 친구들의 참여 자세와 대조하는 방식으로 서술하였다.
#      처리시간: 2.11초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 교실 밖에서 관찰 활동을 하려면 책을 활용한 학습이 선행될 필요가 있다는 내용을 추가하는 게 어때?
#      처리시간: 2.38초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 5번 [A]와 [B] 모두의 첫 번째 발화에서 ‘학생 3’은 자신이 제안한 바에 대한 ‘학생 1’과 ‘학생 2’의 의견을 묻고 있다.
#      처리시간: 1.30초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2번 수용할 점 : 발표회까지 남은 기간을 감안하여, 우리도 몇몇 주목할 식물만 지도에 표시한다.
#
# (나)에서 학생 2는 발표회까지 남은 기간을 감안하여 몇몇 주목할 만한 ...
#      처리시간: 1.91초
#   ✅ 문제 5: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 ㉣ : 각 장소마다 하나씩 대표 식물의 사진을 제시하기로 했으므로 사진을 추가해야겠군.
#      처리시간: 1.36초
#    지문 완료 - 현재 총점: 78점
#
# 🔍 진행률: 11/11 지문
#
# 📖 지문 ID: 2023_11_KICE_43-45
#    지문 길이: 819자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 ㉤
#      처리시간: 2.55초
#   ✅ 문제 2: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 커피박의 올바른 처리 방법과 재활용 분야를 홍보하고, 수거 시설 확충을 제도화할 필요가 있다. 커피박에도 관심을 갖는 책임감 있는 태도가 커피 사랑의 참된 자세이다.
#      처리시간: 1.49초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번 (가) : 커피박을 소각할 때 발생하는 탄소 배출량 수치를, 커피박이 우리 사회에서 관심을 받지 못하고 있는 배경을 보여 주는 자료로 1문단에 추가한다.
#
# 이 선택지는...
#      처리시간: 2.11초
#    지문 완료 - 현재 총점: 85점
#
# ============================================================
# ✅ 테스트 완료: emotional_appeal + gpt-4o
# ⏰ 완료 시간: 2025-05-25 17:53:13
# 📊 최종 결과:
#    총점: 85/100점 (85.0%)
#    정답률: 84.4% (38/45)
#    소요시간: 123.45초
# ============================================================
# ✅ 조합 5 완료
#
# ------------------------------------------------------------
#
# 🚀 테스트 조합 6/6: gpt-4o + expert_role
#
# ============================================================
# 🚀 테스트 시작: gpt-4o + expert_role
# ⏰ 시작 시간: 2025-05-25 17:53:13
# ============================================================
#
# 🔍 진행률: 1/11 지문
#
# 📖 지문 ID: 2023_11_KICE_1-3
#    지문 길이: 978자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 독자의 배경지식, 관점, 읽기 환경, 과제는 독자의 의미 구성에 영향을 주는 독자 요인이다.
#
# 지문에서는 독자의 배경지식이나 관점 등의 독자 요인과 읽기 환경이나 과...
#      처리시간: 2.22초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번 ⓓ에는 ‘독자 자신에게서 답을 찾는 질문’이, ⓔ에는 그에 대한 답을 ‘독자의 경험’에서 찾아내는 모습이 나타난다.
#      처리시간: 1.26초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 스스로 독서 계획을 세우고 자신에게 필요한 책을 찾아 개인적으로 읽는 과정에서 경험할 수 있겠군.
#      처리시간: 1.61초
#    지문 완료 - 현재 총점: 7점
#
# 🔍 진행률: 2/11 지문
#
# 📖 지문 ID: 2023_11_KICE_4-9
#    지문 길이: 2158자, 문제 수: 6
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 (가)는 유서의 특성과 의의를 설명하였고, (나)는 유서 편찬에서 특정 학문의 수용 양상을 시기별로 소개하였다.
#      처리시간: 0.82초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 중국에서는 주로 서적에서 발췌한 내용을 비교하고 해석을 덧붙여 유서를 편찬하였다.
#      처리시간: 1.11초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 평가를 더하는 저술로서 ㉮의 성격은, ㉡에서 중국 학문의 진보성을 확인하고자 서학을 활용한 것에서 나타난다.
#      처리시간: 1.27초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 주자학에 매몰되어 세상의 여러 이치를 연구하지 않는 것은 널리 배우고 익히는 앎의 바른 방법이 아닐 것이다.
#      처리시간: 0.87초
#   ✅ 문제 5: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번
#      처리시간: 1.51초
#   ✅ 문제 6: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 ⓑ : 계몽(啓蒙)하는
#      처리시간: 2.75초
#    지문 완료 - 현재 총점: 20점
#
# 🔍 진행률: 3/11 지문
#
# 📖 지문 ID: 2023_11_KICE_10-13
#    지문 길이: 1192자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 불확정 개념이 사용된 행정 법령에 근거한 행정 작용은 재량 행위인 경우보다 기속 행위인 경우가 많다.
#      처리시간: 2.25초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 재량 준칙이 특정 요건에서 적용된 선례가 없으면 행정청은 동일한 요건이 충족되어도 행정 작용을 할 때 재량 준칙을 따르지 않을 수 있다.
#      처리시간: 1.16초
#   ❌ 문제 3: 예측=1, 정답=2, 점수=0/3
#      응답: 정답: 2번 (나)에서 을의 손해가 80임이 증명된 경우, 갑이 을에게 100을 지급해야 하고 법원이 감액할 수 있다.
#      처리시간: 2.24초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 그분은 우리에게 한 약속을 반드시 ⓔ(지킬) 것이다.
#      처리시간: 1.05초
#    지문 완료 - 현재 총점: 26점
#
# 🔍 진행률: 4/11 지문
#
# 📖 지문 ID: 2023_11_KICE_14-17
#    지문 길이: 1810자, 문제 수: 4
# --------------------------------------------------
#   ❌ 문제 1: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번 ‘L-그래프’에서 직선의 기울기는 가로축과 세로축 두 변수의 증가율의 차이와 동일하다.
#
# 설명: 지문에서는 L-그래프에서 직선의 기울기가 두 변수의 증가율을 비교할 ...
#      처리시간: 3.97초
#   ❌ 문제 2: 예측=5, 정답=4, 점수=0/2
#      응답: 정답: 5번
#
# 5번 선택지는 클라이버의 법칙에 따르면 동물의 체중이 증가함에 따라 에너지의 필요량이 이전 초기 연구에서 생각했던 양보다 많다고 주장하고 있습니다. 그러나 클라이버의...
#      처리시간: 2.20초
#   ❌ 문제 3: 예측=5, 정답=4, 점수=0/2
#      응답: 정답: 5번 ㉠과 ㉡은 모두 생존에 필수적인 최소한의 에너지를 공급하면서 기초 대사량을 구한다.
#      처리시간: 1.23초
#   ✅ 문제 4: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번 최적의 직선을 구한다고 할 때, 최적의 직선의 기울기가 1보다 작다면 ⓐ에 ⓑ가 비례한다고 할 수 없겠군.
#      처리시간: 11.96초
#    지문 완료 - 현재 총점: 29점
#
# 🔍 진행률: 5/11 지문
#
# 📖 지문 ID: 2023_11_KICE_18-21
#    지문 길이: 1934자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 감각적인 배경 묘사를 통해 인물의 행동이 전개되는 상황의 낭만적 분위기를 부각하고 있다.
#      처리시간: 1.40초
#   ✅ 문제 2: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ‘최척’은 옥영의 시에 대한 재능을 결혼 전에 알고 있었지만, 옥영이 시를 읊기 전까지 이를 모른 척했다.
#      처리시간: 1.23초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ㉣은 인물의 행위가 반복적으로 일어나는, ㉤은 ㉣ 중 한 시점을 특정하는 시간의 표지이다.
#      처리시간: 1.42초
#   ✅ 문제 4: 예측=5, 정답=5, 점수=3/3
#      응답: 정답: 5번
#
# 5번 선택지는 최척과 옥영이 재회하여 기쁨을 표현하는 장면을 문제 해결에 따른 기쁨과 또 다른 문제 확인에 따른 불안감으로 해석하고 있습니다. 그러나 이 장면은 두 ...
#      처리시간: 2.60초
#    지문 완료 - 현재 총점: 38점
#
# 🔍 진행률: 6/11 지문
#
# 📖 지문 ID: 2023_11_KICE_22-26
#    지문 길이: 1747자, 문제 수: 5
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 대상에 주목하여 대상과 관련된 가치를 추구하는 자세를 나타내고 있다.
#      처리시간: 1.11초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 [A]의 ‘허물이나 없고자’는 미래에 대한 화자의 바람을, [B]의 ‘티 없어’는 대상을 관찰하기 전에 나타난 화자의 심리를 표현하고 있다.
#      처리시간: 1.08초
#   ✅ 문제 3: 예측=3, 정답=3, 점수=3/3
#      응답: 정답: 3번 (가)의 ‘천석고황’은 이상적 공간에 다다르지 못한 것에 대한 화자의 아쉬움이, (나)의 ‘무릉도원’은 현실적 공간을 이상적 공간으로 바라보는 화자의 인식이 나타난 말...
#      처리시간: 1.69초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=2/2
#      응답: 정답: 3번 ㉠은 화자에게 만족하며 머무르는 삶에 대해, ㉡은 글쓴이에게 허전하지 않은 이유에 대해 생각하게 한다.
#      처리시간: 2.45초
#   ✅ 문제 5: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번
#
# 4번 선택지는 "대상을 회화의 구도상 의미를 지닌 자리로 옮겨 풍경의 원근감을 보이는 그대로 실현해야 한다는 의미"라고 해석하고 있는데, 이는 겸재의 그림이 실물과 ...
#      처리시간: 3.90초
#    지문 완료 - 현재 총점: 49점
#
# 🔍 진행률: 7/11 지문
#
# 📖 지문 ID: 2023_11_KICE_27-30
#    지문 길이: 2441자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 ‘영익’은 가족의 상황을 알고서도 제 생각을 분명히 드러내지 않는다.
#      처리시간: 4.77초
#   ✅ 문제 2: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 [E] : 누가 한 말인지 명시하지 않은 것을 보면, 대화 상황에서 말하는 이와 서술자가 다르다는 사실을 알 수 있다.
#      처리시간: 1.02초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 ‘나’가 계절의 자연스러운 변화와 세월의 흐름을 느끼게 되는 경험적 대상이다.
#      처리시간: 3.97초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2번 ‘집을 고치’던 경험을 바탕으로 ‘구조’가 ‘천박’한 집의 여건을 살펴보는 것에서, 거주 환경의 변화에 적응하여 낯선 공간에 친숙해지고자 하는 ‘나’의 생각을 확인할 ...
#      처리시간: 4.42초
#    지문 완료 - 현재 총점: 58점
#
# 🔍 진행률: 8/11 지문
#
# 📖 지문 ID: 2023_11_KICE_31-34
#    지문 길이: 785자, 문제 수: 4
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 사물의 모습에 대한 긍정적 인식을 바탕으로 중심 제재에 대한 예찬적 태도를 드러내고 있다.
#      처리시간: 0.74초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 ㉣에서 사물을 인격화하여 ‘극진한 축복과 은혜’와 대비되는 화자의 시선을 반영하고 있다.
#      처리시간: 0.93초
#   ✅ 문제 3: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 [B]에서 참나무의 상태에 변화를 가져온 움직임은, [C]에서 버섯이 피어나는 상황과 순차적 관계를 형성한다.
#      처리시간: 1.48초
#   ✅ 문제 4: 예측=3, 정답=3, 점수=3/3
#      응답: 정답: 3번 (가)의 ‘넌출’은 어우러진 생명체들이 현실의 삶에 자족하게 되는, (나)의 ‘홀씨’는 공존하던 생명체들이 흩어지게 되는 계기를 드러내고 있군.
#      처리시간: 1.28초
#    지문 완료 - 현재 총점: 67점
#
# 🔍 진행률: 9/11 지문
#
# 📖 지문 ID: 2023_11_KICE_35-37
#    지문 길이: 1039자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=1, 정답=1, 점수=2/2
#      응답: 정답: 1번 용어의 개념을 정의하여 발표에서 다룰 화제의 범위를 한정하고 있다.
#      처리시간: 6.74초
#   ❌ 문제 2: 예측=3, 정답=5, 점수=0/2
#      응답: 정답: 5번 [자료3]은 달라지는 밝기에 눈이 서서히 적응하도록 조명등의 설치 간격을 달리한다는 내용을 설명하기 위해 ㉢에서 활용하였다.
#      처리시간: 0.76초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 3번 학생 1과 학생 2는 모두, 발표에서 언급된 내용과 관련하여 추가적인 정보를 탐색하려 하고 있다.
#      처리시간: 0.73초
#    지문 완료 - 현재 총점: 69점
#
# 🔍 진행률: 10/11 지문
#
# 📖 지문 ID: 2023_11_KICE_38-42
#    지문 길이: 2367자, 문제 수: 5
# --------------------------------------------------
#   ❌ 문제 1: 예측=3, 정답=4, 점수=0/2
#      응답: 정답: 4번 3문단에서는 식물 조사에 임하는 자신의 참여 자세를 친구들의 참여 자세와 대조하는 방식으로 서술하였다.
#      처리시간: 0.73초
#   ✅ 문제 2: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 교실 밖에서 관찰 활동을 하려면 책을 활용한 학습이 선행될 필요가 있다는 내용을 추가하는 게 어때?
#      처리시간: 2.66초
#   ❌ 문제 3: 예측=1, 정답=3, 점수=0/2
#      응답: 정답: 5번 [A]와 [B] 모두의 첫 번째 발화에서 ‘학생 3’은 자신이 제안한 바에 대한 ‘학생 1’과 ‘학생 2’의 의견을 묻고 있다.
#      처리시간: 2.36초
#   ✅ 문제 4: 예측=2, 정답=2, 점수=3/3
#      응답: 정답: 2번 수용할 점 : 발표회까지 남은 기간을 감안하여, 우리도 몇몇 주목할 식물만 지도에 표시한다.
#      처리시간: 2.63초
#   ✅ 문제 5: 예측=4, 정답=4, 점수=2/2
#      응답: 정답: 4번 ㉣ : 각 장소마다 하나씩 대표 식물의 사진을 제시하기로 했으므로 사진을 추가해야겠군.
#      처리시간: 5.59초
#    지문 완료 - 현재 총점: 76점
#
# 🔍 진행률: 11/11 지문
#
# 📖 지문 ID: 2023_11_KICE_43-45
#    지문 길이: 819자, 문제 수: 3
# --------------------------------------------------
#   ✅ 문제 1: 예측=5, 정답=5, 점수=2/2
#      응답: 정답: 5번 ㉤
#      처리시간: 0.78초
#   ✅ 문제 2: 예측=2, 정답=2, 점수=2/2
#      응답: 정답: 2번 커피박의 올바른 처리 방법과 재활용 분야를 홍보하고, 수거 시설 확충을 제도화할 필요가 있다. 커피박에도 관심을 갖는 책임감 있는 태도가 커피 사랑의 참된 자세이다.
#      처리시간: 0.91초
#   ✅ 문제 3: 예측=1, 정답=1, 점수=3/3
#      응답: 정답: 1번 (가)
#      처리시간: 0.65초
#    지문 완료 - 현재 총점: 83점
#
# ============================================================
# ✅ 테스트 완료: expert_role + gpt-4o
# ⏰ 완료 시간: 2025-05-25 17:55:15
# 📊 최종 결과:
#    총점: 83/100점 (83.0%)
#    정답률: 82.2% (37/45)
#    소요시간: 122.22초
# ============================================================
# ✅ 조합 6 완료
#
# ------------------------------------------------------------
#
# ====================================================================================================
# 📊 종합 결과 비교 테이블
# ====================================================================================================
# 모델              프롬프트               정답률      총점       정답수/총문제      실행시간
# ----------------------------------------------------------------------------------------------------
# gpt-4o          zero_shot          95.6%    96       43/45        97.2초
# gpt-4o          emotional_appeal   84.4%    85       38/45        123.4초
# gpt-4o          expert_role        82.2%    83       37/45        122.2초
# gpt-4o-mini     zero_shot          71.1%    71       32/45        97.7초
# gpt-4o-mini     expert_role        57.8%    58       26/45        189.4초
# gpt-4o-mini     emotional_appeal   55.6%    56       25/45        140.1초
# ----------------------------------------------------------------------------------------------------
# !! 최고 성능: gpt-4o + zero_shot
#    정답률: 95.6% | 총점: 96점 | 시간: 97.2초
#
# 📈 프롬프트별 평균 성능:
#   zero_shot         : 평균 정답률 83.3% | 평균 시간 97.5초
#   emotional_appeal  : 평균 정답률 70.0% | 평균 시간 131.8초
#   expert_role       : 평균 정답률 70.0% | 평균 시간 155.8초
#
# 🤖 모델별 평균 성능:
#   gpt-4o-mini    : 평균 정답률 61.5% | 평균 시간 142.4초
#   gpt-4o         : 평균 정답률 87.4% | 평균 시간 114.3초
#
# ====================================================================================================
# 📊 종합 결과 비교 테이블
# ====================================================================================================
# 모델              프롬프트               정답률      총점       정답수/총문제      실행시간
# ----------------------------------------------------------------------------------------------------
# gpt-4o          zero_shot          95.6%    96       43/45        97.2초
# gpt-4o          emotional_appeal   84.4%    85       38/45        123.4초
# gpt-4o          expert_role        82.2%    83       37/45        122.2초
# gpt-4o-mini     zero_shot          71.1%    71       32/45        97.7초
# gpt-4o-mini     expert_role        57.8%    58       26/45        189.4초
# gpt-4o-mini     emotional_appeal   55.6%    56       25/45        140.1초
# ----------------------------------------------------------------------------------------------------
# !! 최고 성능: gpt-4o + zero_shot
#    정답률: 95.6% | 총점: 96점 | 시간: 97.2초
#
# 📈 프롬프트별 평균 성능:
#   zero_shot         : 평균 정답률 83.3% | 평균 시간 97.5초
#   emotional_appeal  : 평균 정답률 70.0% | 평균 시간 131.8초
#   expert_role       : 평균 정답률 70.0% | 평균 시간 155.8초
#
# 🤖 모델별 평균 성능:
#   gpt-4o-mini    : 평균 정답률 61.5% | 평균 시간 142.4초
#   gpt-4o         : 평균 정답률 87.4% | 평균 시간 114.3초
#
# 🔍 상세 분석:
#
# 📋 프롬프트별 응답 예시:
#
# ============================================================
# 📝 gpt-4o-mini + zero_shot
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4...
#
# ❌ 오답 예시:
#   문제: 다음은 학생이 독서 후 작성한 글의 일부이다. [A]를 바탕으로 ⓐ～ⓔ를 이해한 내용으로 가장 적절한 것은?...
#   예측: 4 | 정답: 5
#   응답: 정답: 4번...
#
#
# ============================================================
# 📝 gpt-4o-mini + emotional_appeal
# ============================================================
# ✅ 정답 예시:
#   문제: 다음은 학생이 독서 후 작성한 글의 일부이다. [A]를 바탕으로 ⓐ～ⓔ를 이해한 내용으로 가장 적절한 것은?...
#   예측: 5 | 정답: 5
#   응답: 정답: 5번 ⓓ에는 ‘독자 자신에게서 답을 찾는 질문’이, ⓔ에는 그에 대한 답을 ‘독자의 경험’에서 찾아내는 모습이 나타난다.
#
# 이유: ⓓ에서 학생은 "내가 진정으로 좋아하는 일이 무엇인지 나에게 묻게 되었다."라는 질문을 통해 자신에게서 답을 찾고 있으며, ⓔ에서...
#
# ❌ 오답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 2 | 정답: 4
#   응답: 정답: 2번
#
# 이유: 지문에서는 다른 독자와의 소통이 독자의 인식의 폭을 확장하도록 돕는다고 명시적으로 언급하지 않고 있습니다. 오히려 독자는 독서 모임이나 독서 동아리에서 다른 독자들과 나누는 과정을 통해 자신의 인식을 심화 확장할 수 있다고 설명하고 있습니다. 따라...
#
#
# ============================================================
# 📝 gpt-4o-mini + expert_role
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4번
#
# 해설: 지문에서는 독자의 배경지식, 관점, 읽기 환경, 과제 등이 독자의 의미 구성에 영향을 미친다고 언급하고 있지만, 이를 '독자 요인'으로 명시적으로 구분하지는 않았습니다. 따라서 4번 선택지는 지문의 내용과 일치하지 않는 것으로 판단됩니다....
#
# ❌ 오답 예시:
#   문제: 다음은 학생이 독서 후 작성한 글의 일부이다. [A]를 바탕으로 ⓐ～ⓔ를 이해한 내용으로 가장 적절한 것은?...
#   예측: 4 | 정답: 5
#   응답: 정답: 4번
#
# 해설:
# - ⓐ는 "음악 시간에 들었던 베토벤의 교향곡 <합창>이 위대한 작품인 이유는 무엇일까?"라는 질문으로, 이는 독자가 책에서 답을 찾으려는 질문입니다.
# - ⓑ는 "이 곡이 낭만주의 음악의 특징을 보여 준다고 했다."라는 내용으로, 이는 책에서 제시...
#
#
# ============================================================
# 📝 gpt-4o + zero_shot
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4번...
#
# ❌ 오답 예시:
#   문제: 윗글을 읽고 추론한 내용으로 적절하지 않은 것은?...
#   예측: 5 | 정답: 4
#   응답: 정답: 5번...
#
#
# ============================================================
# 📝 gpt-4o + emotional_appeal
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4번 독자의 배경지식, 관점, 읽기 환경, 과제는 독자의 의미 구성에 영향을 주는 독자 요인이다.
#
# 지문에서는 독자의 배경지식이나 관점 등의 독자 요인과 읽기 환경이나 과제 등의 상황 요인이 다르다고 언급하고 있습니다. 따라서 읽기 환경과 과제는 독자 요인이 ...
#
# ❌ 오답 예시:
#   문제: 윗글을 바탕으로 <보기>를 이해한 내용으로 가장 적절한 것은? [3점]...
#   예측: 1 | 정답: 2
#   응답: 정답: 2번 (나)에서 을의 손해가 80임이 증명된 경우, 갑이 을에게 100을 지급해야 하고 법원이 감액할 수 있다.
#
# 설명:
# - (가) 상황에서는 위약금 약정이 없으므로, 을은 손해를 증명해야 하고, 증명된 손해액인 80만큼만 받을 수 있습니다.
# - (나) 상황에...
#
#
# ============================================================
# 📝 gpt-4o + expert_role
# ============================================================
# ✅ 정답 예시:
#   문제: 윗글의 내용과 일치하지 않는 것은?...
#   예측: 4 | 정답: 4
#   응답: 정답: 4번 독자의 배경지식, 관점, 읽기 환경, 과제는 독자의 의미 구성에 영향을 주는 독자 요인이다.
#
# 지문에서는 독자의 배경지식이나 관점 등의 독자 요인과 읽기 환경이나 과제 등의 상황 요인이 다르다고 언급하고 있습니다. 따라서 읽기 환경과 과제는 독자 요인이 ...
#
# ❌ 오답 예시:
#   문제: 윗글을 바탕으로 <보기>를 이해한 내용으로 가장 적절한 것은? [3점]...
#   예측: 1 | 정답: 2
#   응답: 정답: 2번 (나)에서 을의 손해가 80임이 증명된 경우, 갑이 을에게 100을 지급해야 하고 법원이 감액할 수 있다....
#
#
# 💾 종합 결과 저장 완료:
#    - JSON 요약: data/results/comprehensive_summary.json
#    - CSV 요약: data/results/comprehensive_summary.csv
#    - 개별 상세 결과: data/results/ 폴더의 각 CSV 파일들
# 전체 테스트 셀이 준비되었습니다.
# 필요시 위의 주석을 해제하고 실행하세요.

# %%
# 개별 문제로 테스트해보기 (디버깅 및 확인용)
print("🔍 개별 문제 테스트")
print("=" * 50)

if solver.grouped_data:
    # 첫 번째 지문의 첫 번째 문제로 테스트
    first_paragraph = solver.grouped_data[0]
    first_problem = first_paragraph['problems'][0]
    
    print(f"📖 테스트 지문 ID: {first_paragraph['id']}")
    print(f"📝 테스트 문제:")
    print(f"   {first_problem['question'][:200]}...")
    
    # 프롬프트 생성 테스트
    for prompt_name in ["zero_shot", "emotional_appeal", "expert_role"]:
        print(f"\n💡 {prompt_name} 프롬프트:")
        try:
            prompt = solver.build_prompt_for_problem(
                prompt_name, 
                first_paragraph['paragraph'], 
                first_problem
            )
            print(f"   프롬프트 길이: {len(prompt)}자")
            print(f"   프롬프트 미리보기: {prompt[:300]}...")
        except Exception as e:
            print(f"   ❌ 프롬프트 생성 실패: {e}")
# Out:
# 🔍 개별 문제 테스트
# ==================================================
# 📖 테스트 지문 ID: 2023_11_KICE_1-3
# 📝 테스트 문제:
#    윗글의 내용과 일치하지 않는 것은?...
#
# 💡 zero_shot 프롬프트:
#    프롬프트 길이: 1356자
#    프롬프트 미리보기: 다음 지문을 읽고 문제를 풀어주세요.
#
#     지문:
#     사람들이 지속적으로 책을 읽는 이유 중 하나는 즐거움이다. 독서의 즐거움에는 여러 가지가 있겠지만 그 중심에는 ‘소통의 즐거움’이 있다.독자는 독서를 통해 책과 소통하는 즐거움을 경험한다. 독서는필자와 간접적으로 대화하는 소통 행위이다. 독자는 자신이 속한사회나 시대의 영향 아래 필자가 속해 있거나 드러내고자 하는 사회나 시대를 경험한다. 직접 경험하지 못했던 다양한 삶을 필자를 매개로 만나고 이해하면서 독자는 더 넓은 시야로 세계를바라볼 수 있다. 이때 같은 책을 읽은 ...
#
# 💡 emotional_appeal 프롬프트:
#    프롬프트 길이: 1671자
#    프롬프트 미리보기: 🎯 인생에서 최고로 중요한 수능 국어 문제입니다.
#     당신이 소중하게 생각하는 할머니께서 당신이 좋은 성적을 얻기만을 기다리고 계십니다. 당신의 실력을 보여주세요.
#     이 문제는 많은 수험생들이 어려워하는 유형입니다. 하지만 당신은 분명히 풀 수 있습니다!
#     차근차근 읽고, 단계별로 생각해서 최선의 답을 찾아주세요.
#     자신감을 가지고 열정적으로 풀어보세요.
#
#     지문:
#     사람들이 지속적으로 책을 읽는 이유 중 하나는 즐거움이다. 독서의 즐거움에는 여러 가지가 있겠지만 그 중심에는 ‘소통의 즐거움’이 있다...
#
# 💡 expert_role 프롬프트:
#    프롬프트 길이: 1364자
#    프롬프트 미리보기:
#     당신은 국어교육 전문가입니다. 다음 지문과 문제를 분석하여 정확한 답을 제시해주세요.
#
#     지문:
#     사람들이 지속적으로 책을 읽는 이유 중 하나는 즐거움이다. 독서의 즐거움에는 여러 가지가 있겠지만 그 중심에는 ‘소통의 즐거움’이 있다.독자는 독서를 통해 책과 소통하는 즐거움을 경험한다. 독서는필자와 간접적으로 대화하는 소통 행위이다. 독자는 자신이 속한사회나 시대의 영향 아래 필자가 속해 있거나 드러내고자 하는 사회나 시대를 경험한다. 직접 경험하지 못했던 다양한 삶을 필자를 매개로 만나고 이해하면서 독자는 더 ...

# %%
# 저장된 결과 확인
print("📊 저장된 결과 확인")
print("=" * 50)

if solver.results:
    for name, result in solver.results.items():
        print(f"\n📈 {name} 결과:")
        print(f"   정답률: {result.score:.1f}%")
        print(f"   총점: {result.total_score}점")
        print(f"   실행시간: {result.execution_time:.2f}초")
        
        # DataFrame 미리보기
        df = result.detailed_results
        print(f"   데이터프레임 형태: {df.shape}")
        print(f"   컬럼: {list(df.columns)}")
        
        # 처음 3개 결과 미리보기
        print(f"\n   📋 처음 3개 결과:")
        for i in range(min(3, len(df))):
            row = df.iloc[i]
            status = "✅" if row['is_correct'] else "❌"
            print(f"      {status} 문제 {i+1}: 예측={row['pred']}, 정답={row['answer']}, 점수={row['score']}")
else:
    print("저장된 결과가 없습니다. 먼저 테스트를 실행하세요.")
# Out:
# 📊 저장된 결과 확인
# ==================================================
#
# 📈 zero_shot_gpt-4o-mini 결과:
#    정답률: 71.1%
#    총점: 71점
#    실행시간: 97.71초
#    데이터프레임 형태: (45, 10)
#    컬럼: ['paragraph_id', 'problem_num', 'question', 'pred', 'answer', 'score', 'max_score', 'is_correct', 'response', 'processing_time']
#
#    📋 처음 3개 결과:
#       ✅ 문제 1: 예측=4, 정답=4, 점수=2
#       ❌ 문제 2: 예측=4, 정답=5, 점수=0
#       ✅ 문제 3: 예측=1, 정답=1, 점수=2
#
# 📈 emotional_appeal_gpt-4o-mini 결과:
#    정답률: 55.6%
#    총점: 56점
#    실행시간: 140.15초
#    데이터프레임 형태: (45, 10)
#    컬럼: ['paragraph_id', 'problem_num', 'question', 'pred', 'answer', 'score', 'max_score', 'is_correct', 'response', 'processing_time']
#
#    📋 처음 3개 결과:
#       ❌ 문제 1: 예측=2, 정답=4, 점수=0
#       ✅ 문제 2: 예측=5, 정답=5, 점수=3
#       ✅ 문제 3: 예측=1, 정답=1, 점수=2
#
# 📈 expert_role_gpt-4o-mini 결과:
#    정답률: 57.8%
#    총점: 58점
#    실행시간: 189.41초
#    데이터프레임 형태: (45, 10)
#    컬럼: ['paragraph_id', 'problem_num', 'question', 'pred', 'answer', 'score', 'max_score', 'is_correct', 'response', 'processing_time']
#
#    📋 처음 3개 결과:
#       ✅ 문제 1: 예측=4, 정답=4, 점수=2
#       ❌ 문제 2: 예측=4, 정답=5, 점수=0
#       ✅ 문제 3: 예측=1, 정답=1, 점수=2
#
# 📈 zero_shot_gpt-4o 결과:
#    정답률: 95.6%
#    총점: 96점
#    실행시간: 97.24초
#    데이터프레임 형태: (45, 10)
#    컬럼: ['paragraph_id', 'problem_num', 'question', 'pred', 'answer', 'score', 'max_score', 'is_correct', 'response', 'processing_time']
#
#    📋 처음 3개 결과:
#       ✅ 문제 1: 예측=4, 정답=4, 점수=2
#       ✅ 문제 2: 예측=5, 정답=5, 점수=3
#       ✅ 문제 3: 예측=1, 정답=1, 점수=2
#
# 📈 emotional_appeal_gpt-4o 결과:
#    정답률: 84.4%
#    총점: 85점
#    실행시간: 123.45초
#    데이터프레임 형태: (45, 10)
#    컬럼: ['paragraph_id', 'problem_num', 'question', 'pred', 'answer', 'score', 'max_score', 'is_correct', 'response', 'processing_time']
#
#    📋 처음 3개 결과:
#       ✅ 문제 1: 예측=4, 정답=4, 점수=2
#       ✅ 문제 2: 예측=5, 정답=5, 점수=3
#       ✅ 문제 3: 예측=1, 정답=1, 점수=2
#
# 📈 expert_role_gpt-4o 결과:
#    정답률: 82.2%
#    총점: 83점
#    실행시간: 122.22초
#    데이터프레임 형태: (45, 10)
#    컬럼: ['paragraph_id', 'problem_num', 'question', 'pred', 'answer', 'score', 'max_score', 'is_correct', 'response', 'processing_time']
#
#    📋 처음 3개 결과:
#       ✅ 문제 1: 예측=4, 정답=4, 점수=2
#       ✅ 문제 2: 예측=5, 정답=5, 점수=3
#       ✅ 문제 3: 예측=1, 정답=1, 점수=2

# %% [markdown]
# ## 🧪 프롬프트 비교 분석

# %%
# 프롬프트별 성능 비교 분석
def compare_prompts(solver, model="gpt-4o-mini", num_questions=5):
    """동일한 모델로 다른 프롬프트들의 성능 비교"""
    print(f"🔬 프롬프트 비교 분석: {model} ({num_questions}문제)")
    print("=" * 60)
    
    prompts = ["zero_shot", "emotional_appeal", "expert_role"]
    results = {}
    
    for prompt in prompts:
        print(f"\n🧪 {prompt} 테스트 중...")
        try:
            result = solver.run_test(prompt, model, num_questions)
            results[prompt] = result
            print(f"   ✅ {prompt}: {result.score:.1f}% 정답률")
        except Exception as e:
            print(f"   ❌ {prompt}: 테스트 실패 - {e}")
    
    # 결과 비교
    if results:
        print(f"\n📊 프롬프트 비교 결과:")
        print("-" * 40)
        sorted_results = sorted(results.items(), key=lambda x: x[1].score, reverse=True)
        
        for i, (prompt, result) in enumerate(sorted_results):
            rank = "🥇" if i == 0 else "🥈" if i == 1 else "🥉"
            print(f"{rank} {prompt:<18}: {result.score:.1f}% ({result.total_score}점)")
    
    return results

print("🔬 프롬프트 비교 분석 함수가 정의되었습니다.")
print("사용법: compare_prompts(solver, 'gpt-4o-mini', 5)")

# 예시 실행 (주석 해제하여 사용하기!)
# prompt_comparison = compare_prompts(solver, 'gpt-4o-mini', 5)
# Out:
# 🔬 프롬프트 비교 분석 함수가 정의되었습니다.
# 사용법: compare_prompts(solver, 'gpt-4o-mini', 5)
